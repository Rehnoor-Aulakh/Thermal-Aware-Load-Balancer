# %% [markdown]
# # Part 1: Imports and Configuration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (mean_absolute_error, mean_squared_error, r2_score)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Input, LSTM, Dense, Dropout)

from tensorflow.keras.callbacks import (EarlyStopping, ReduceLROnPlateau, ModelCheckpoint)

import joblib
import random
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783391301.561999    5657 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1783391304.858994    5657 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783391326.945078    5657 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
SEED = 42
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# Configuration

# %%
# Approximate Sensor interval

SAMPLE_INTERVAL_SECONDS = 2

# Use Previous 60 seconds
LOOKBACK_SECONDS = 60

#Predict 60 seconds into the future
FORECAST_SECONDS = 60

LOOKBACK = LOOKBACK_SECONDS // SAMPLE_INTERVAL_SECONDS
HORIZON = FORECAST_SECONDS // SAMPLE_INTERVAL_SECONDS

print("Lookback samples: ",LOOKBACK)
print("Forecast Horizon samples: ", HORIZON)
# Out:
# Lookback samples:  30
# Forecast Horizon samples:  30

# %% [markdown]
# # Part 2: Loading Datasets

# %%
FILES = {
    "manan": "manan_merged_experiment.csv",
    "prabhsimrat": "prabh_merged_experiment.csv"
    # "sushant":
}

# %%
datasets ={}

for name, path in FILES.items():
    df = pd.read_csv(path)
    df["timestamp"]= pd.to_datetime(df["timestamp"])
    df = df.sort_values("timestamp").reset_index(drop= True)
    df["source"] = name
    datasets[name]= df
    print(name, "-", df.shape)
# Out:
# manan - (14803, 13)
# prabhsimrat - (15365, 13)

# %%
FEATURE_COLS = [
    "cpuUsage",
    "ramUsage",
    "networkConnections",
    "processCount",
    "cpuPackagePower",
    "cpuTemperature"
]

# %%
for name, df in datasets.items():

    print(f"\n===== {name} =====")

    print(
        df[
            [
                "cpuUsage",
                "cpuPackagePower",
                "cpuAverageClock",
                "cpuTemperature"
            ]
        ].describe().loc[
            ["min", "mean", "std", "max"]
        ]
    )
# Out:
# ===== manan =====
#         cpuUsage  cpuPackagePower  cpuAverageClock  cpuTemperature
# min     9.200000         9.600000       403.200000       60.000000
# mean   58.584071        40.438654      2419.553636       86.093292
# std    30.660576        15.644110       471.266927       11.716394
# max   100.000000        66.600000      2973.600000       99.000000
#
# ===== prabhsimrat =====
#         cpuUsage  cpuPackagePower  cpuAverageClock  cpuTemperature
# min     1.000000         6.000000      2810.000000       64.100000
# mean   49.854247        29.637592      3617.252652       87.949492
# std    34.927009        11.036970       287.802921       10.251866
# max   100.000000        50.900000      4492.000000       95.900000

# %% [markdown]
# # Part 3: Cleaning

# %% [markdown]
# After running (after_stress_generator.ipynb)- most of the cleaning is already done

# %%
def clean_run(df):
    df = df.copy()
    # Keep only valid sensor data
    df = df.dropna(subset = FEATURE_COLS)
    df = df.sort_values(
        "timestamp"
    ).reset_index(drop=True)

    return df

# %%
for name in datasets:

    datasets[name] = clean_run(
        datasets[name]
    )

    print(
        name,
        len(datasets[name])
    )
# Out:
# manan 14803
# prabhsimrat 15365

# %% [markdown]
# # Checking Sampling Gaps

# %%
def inspect_time_gaps(df, name):

    gaps = (
        df["timestamp"]
        .diff()
        .dt.total_seconds()
    )

    print(f"\n{name}")

    print(
        "Median interval:",
        gaps.median()
    )

    print(
        "Maximum gap:",
        gaps.max()
    )

    print(
        "Gaps > 5 seconds:",
        (gaps > 5).sum()
    )

# %%
for name, df in datasets.items():

    inspect_time_gaps(
        df,
        name
    )
# Out:
# manan
# Median interval: 2.0298681
# Maximum gap: 4.3050749
# Gaps > 5 seconds: 0
#
# prabhsimrat
# Median interval: 2.02355955
# Maximum gap: 7.0642233
# Gaps > 5 seconds: 1

# %% [markdown]
# # Part 6: Create Balanced Time Blocks

# %%
TRAIN_RUNS = ["manan", "prabhsimrat"]
TEST_RUNS = ["manan", "prabhsimrat"]

# %%
BLOCK_MINUTES = 10

TRAIN_RATIO = 0.7
VAL_RATIO = 0.15
TEST_RATIO = 0.15

# %%
def get_phase_group(mode):

    mode = str(mode).upper()

    if "COOLING" in mode:
        return "COOLING"

    if mode in [
        "INITIAL_IDLE",
        "PRE_EXPERIMENT",
        "POST_EXPERIMENT"
    ]:
        return "IDLE"

    if mode in [
        "RAMP",
        "CHAOS",
        "TRANSITION",
        "MIXED"
    ]:
        return mode

    return "OTHER"

# %%
for name, df in datasets.items():

    df = df.copy()

    df["phaseGroup"] = (
        df["mode"]
        .apply(get_phase_group)
    )

    datasets[name] = df

    print(f"\n===== {name} =====")

    print(
        df["phaseGroup"]
        .value_counts()
    )
# Out:
# ===== manan =====
# phaseGroup
# MIXED         5298
# CHAOS         2658
# RAMP          2656
# TRANSITION    2654
# OTHER          739
# COOLING        739
# IDLE            59
# Name: count, dtype: int64
#
# ===== prabhsimrat =====
# phaseGroup
# MIXED         5306
# CHAOS         2669
# RAMP          2664
# TRANSITION    2656
# OTHER         1574
# COOLING        445
# IDLE            51
# Name: count, dtype: int64

# %% [markdown]
# Now Creating Contiguous Blocks

# %%
def create_time_blocks(df, run_name, block_minutes = 10):
    df = df.copy()
    df = df.sort_values("timestamp").reset_index(drop= True)
    all_blocks = []
    block_counter = 0
    
    # --------------------- Processing Each Contiguous Phase Separately----------------------------
    
    phase_change = (df["phaseGroup"]!=df["phaseGroup"].shift())
    
    df["phaseSegment"]= (phase_change.cumsum())
    
    for segment_id, segment in df.groupby("phaseSegment"):
        segment = (segment.sort_values("timestamp").copy())
        phase = (segment["phaseGroup"].iloc[0])
        segment_start = (segment["timestamp"].min())
        
        # Assign 10 minute block number
        elapsed_minutes = (segment["timestamp"] - segment_start).dt.total_seconds() / 60
        
        segment["localBlock"] = (elapsed_minutes // block_minutes).astype(int)
        
        for local_block, block in segment.groupby("localBlock"):
            block = block.copy()
            block["blockId"] = (f"{run_name}"
                                f"{block_counter}")
            block["runName"] = run_name
            all_blocks.append(block)
            block_counter+=1
    
    return all_blocks

# %%
all_blocks = []

for name in TRAIN_RUNS:

    run_blocks = create_time_blocks(

        df=datasets[name],

        run_name=name,

        block_minutes=BLOCK_MINUTES
    )

    all_blocks.extend(
        run_blocks
    )

    print(
        name,
        "blocks:",
        len(run_blocks)
    )
# Out:
# manan blocks: 54
# prabhsimrat blocks: 55

# %% [markdown]
# # 7. Remove Blocks that are too short

# %%
MIN_REQUIRED_SAMPLES = (
    LOOKBACK
    + HORIZON
    + 5
)

# %%
valid_blocks = []

removed_blocks = []

for block in all_blocks:

    if len(block) >= MIN_REQUIRED_SAMPLES:

        valid_blocks.append(block)

    else:

        removed_blocks.append(block)


print(
    "Valid blocks:",
    len(valid_blocks)
)

print(
    "Removed short blocks:",
    len(removed_blocks)
)
# Out:
# Valid blocks: 106
# Removed short blocks: 3

# %%
block_summary = []

for block in valid_blocks:

    block_summary.append({

        "blockId":
            block["blockId"].iloc[0],

        "runName":
            block["runName"].iloc[0],

        "phaseGroup":
            block["phaseGroup"].iloc[0],

        "samples":
            len(block),

        "startTime":
            block["timestamp"].min(),

        "endTime":
            block["timestamp"].max()
    })


block_summary = pd.DataFrame(
    block_summary
)

display(
    block_summary.head(20)
)
# Out:
#     blockId runName phaseGroup  samples                           startTime  \
# 0    manan2   manan       RAMP      296 2026-07-06 02:17:52.834077200+05:30
# 1    manan3   manan       RAMP      295 2026-07-06 02:27:53.976796400+05:30
# 2    manan4   manan       RAMP      295 2026-07-06 02:37:54.652708500+05:30
# 3    manan5   manan       RAMP      296 2026-07-06 02:47:53.518745400+05:30
# 4    manan6   manan       RAMP      292 2026-07-06 02:57:54.002098900+05:30
# 5    manan7   manan       RAMP      296 2026-07-06 03:07:52.939946600+05:30
# 6    manan8   manan       RAMP      296 2026-07-06 03:17:53.410543100+05:30
# 7    manan9   manan       RAMP      295 2026-07-06 03:27:54.375094400+05:30
# 8   manan10   manan       RAMP      295 2026-07-06 03:37:54.764023700+05:30
# 9   manan11   manan    COOLING      147 2026-07-06 03:47:53.510465900+05:30
# 10  manan12   manan      CHAOS      294 2026-07-06 03:52:52.141073800+05:30
# 11  manan13   manan      CHAOS      295 2026-07-06 04:02:52.703170500+05:30
# 12  manan14   manan      CHAOS      296 2026-07-06 04:12:52.462886600+05:30
# 13  manan15   manan      CHAOS      296 2026-07-06 04:22:53.249696800+05:30
# 14  manan16   manan      CHAOS      295    2026-07-06 04:32:53.693924+05:30
# 15  manan17   manan      CHAOS      295    2026-07-06 04:42:52.239192+05:30
# 16  manan18   manan      CHAOS      296    2026-07-06 04:52:52.679917+05:30
# 17  manan19   manan      CHAOS      296 2026-07-06 05:02:52.890880800+05:30
# 18  manan20   manan      CHAOS      295 2026-07-06 05:12:53.889148100+05:30
# 19  manan21   manan    COOLING      148 2026-07-06 05:22:52.613301500+05:30
#
#                                endTime
# 0  2026-07-06 02:27:51.946574700+05:30
# 1  2026-07-06 02:37:52.628830900+05:30
# 2  2026-07-06 02:47:51.481890400+05:30
# 3  2026-07-06 02:57:51.959968500+05:30
# 4  2026-07-06 03:07:50.885778200+05:30
# 5  2026-07-06 03:17:51.375515200+05:30
# 6  2026-07-06 03:27:52.352622600+05:30
# 7  2026-07-06 03:37:52.734991300+05:30
# 8  2026-07-06 03:47:51.479478400+05:30
# 9  2026-07-06 03:52:50.110064800+05:30
# 10 2026-07-06 04:02:50.677776900+05:30
# 11 2026-07-06 04:12:50.404444100+05:30
# 12 2026-07-06 04:22:51.226516800+05:30
# 13 2026-07-06 04:32:51.664639200+05:30
# 14    2026-07-06 04:42:50.215583+05:30
# 15 2026-07-06 04:52:50.647325800+05:30
# 16 2026-07-06 05:02:50.864456600+05:30
# 17 2026-07-06 05:12:51.854961200+05:30
# 18 2026-07-06 05:22:50.590382100+05:30
# 19 2026-07-06 05:27:51.142583300+05:30

# %%
print(
    block_summary[
        "phaseGroup"
    ].value_counts()
)
# Out:
# phaseGroup
# MIXED         36
# RAMP          18
# CHAOS         18
# TRANSITION    18
# OTHER          9
# COOLING        7
# Name: count, dtype: int64

# %% [markdown]
# # 8. Split whole blocks into train, validation and internal test

# %%
from sklearn.model_selection import train_test_split

# %%
def split_blocks_balanced(
    block_summary,
    seed=42
):

    train_ids = []
    val_ids = []
    test_ids = []

    # ----------------------------------------
    # Split separately by:
    # device + experiment phase
    # ----------------------------------------

    grouped = block_summary.groupby(
        [
            "runName",
            "phaseGroup"
        ]
    )


    for (
        run_name,
        phase
    ), group in grouped:

        ids = (
            group["blockId"]
            .tolist()
        )


        # Reproducible random order
        rng = np.random.default_rng(
            seed
        )

        rng.shuffle(ids)


        n = len(ids)


        print(
            run_name,
            phase,
            "blocks:",
            n
        )


        # ------------------------------------
        # Very small groups
        # ------------------------------------

        if n == 1:

            train_ids.extend(ids)

            continue


        if n == 2:

            train_ids.append(ids[0])
            val_ids.append(ids[1])

            continue


        # ------------------------------------
        # Normal groups
        # ------------------------------------

        n_train = max(
            1,
            int(round(n * TRAIN_RATIO))
        )

        n_val = max(
            1,
            int(round(n * VAL_RATIO))
        )


        # Ensure at least one test block
        if (
            n_train
            + n_val
            >= n
        ):

            n_train = n - 2
            n_val = 1
            

        train_ids.extend(
            ids[:n_train]
        )


        val_ids.extend(
            ids[
                n_train:
                n_train + n_val
            ]
        )


        test_ids.extend(
            ids[
                n_train + n_val:
            ]
        )


    return (
        train_ids,
        val_ids,
        test_ids
    )

# %%
(
    train_block_ids,
    val_block_ids,
    test_block_ids

) = split_blocks_balanced(
    block_summary,
    seed=SEED
)
# Out:
# manan CHAOS blocks: 9
# manan COOLING blocks: 4
# manan MIXED blocks: 18
# manan OTHER blocks: 3
# manan RAMP blocks: 9
# manan TRANSITION blocks: 9
# prabhsimrat CHAOS blocks: 9
# prabhsimrat COOLING blocks: 3
# prabhsimrat MIXED blocks: 18
# prabhsimrat OTHER blocks: 6
# prabhsimrat RAMP blocks: 9
# prabhsimrat TRANSITION blocks: 9

# %%
print(
    "\nTraining blocks:",
    len(train_block_ids)
)

print(
    "Validation blocks:",
    len(val_block_ids)
)

print(
    "Internal test blocks:",
    len(test_block_ids)
)
# Out:
# Training blocks: 70
# Validation blocks: 16
# Internal test blocks: 20

# %%
block_summary["split"] = (
    "UNASSIGNED"
)

block_summary.loc[

    block_summary["blockId"]
    .isin(train_block_ids),

    "split"

] = "TRAIN"


block_summary.loc[

    block_summary["blockId"]
    .isin(val_block_ids),

    "split"

] = "VALIDATION"


block_summary.loc[

    block_summary["blockId"]
    .isin(test_block_ids),

    "split"

] = "TEST"

# %%
coverage = pd.crosstab(

    block_summary["phaseGroup"],

    block_summary["split"]
)

display(coverage)
# Out:
# split       TEST  TRAIN  VALIDATION
# phaseGroup
# CHAOS          4     12           2
# COOLING        2      3           2
# MIXED          4     26           6
# OTHER          2      5           2
# RAMP           4     12           2
# TRANSITION     4     12           2

# %%
device_coverage = pd.crosstab(

    block_summary["runName"],

    block_summary["split"]
)

display(device_coverage)
# Out:
# split        TEST  TRAIN  VALIDATION
# runName
# manan          10     34           8
# prabhsimrat    10     36           8

# %% [markdown]
# # 10. Converting IDs back to block lists

# %%
train_blocks = []

val_blocks = []

test_blocks = []


for block in valid_blocks:

    block_id = (
        block["blockId"]
        .iloc[0]
    )


    if block_id in train_block_ids:

        train_blocks.append(
            block
        )


    elif block_id in val_block_ids:

        val_blocks.append(
            block
        )


    elif block_id in test_block_ids:

        test_blocks.append(
            block
        )

# %%
print(
    "Train blocks:",
    len(train_blocks)
)

print(
    "Validation blocks:",
    len(val_blocks)
)

print(
    "Internal test blocks:",
    len(test_blocks)
)
# Out:
# Train blocks: 70
# Validation blocks: 16
# Internal test blocks: 20

# %% [markdown]
# # Part 11: Fitting the scaler on traininig blocks only

# %%
scaler_training_data = pd.concat(

    [
        block[FEATURE_COLS]
        for block in train_blocks
    ],

    ignore_index=True
)

# %%
scaler_X = StandardScaler()

scaler_X.fit(
    scaler_training_data
)
# Out:
# StandardScaler()

# %%
joblib.dump(

    scaler_X,

    "cross_device_feature_scaler.pkl"
)

print(
    "Scaler fitted only on training blocks."
)
# Out:
# Scaler fitted only on training blocks.

# %% [markdown]
# # Part 12: Create sequences inside each block

# %%
def create_sequences_from_block(
    block,
    scaler,
    lookback,
    horizon,
    max_gap_seconds=5
):

    block = (
        block
        .sort_values("timestamp")
        .reset_index(drop=True)
        .copy()
    )


    scaled_features = scaler.transform(
        block[FEATURE_COLS]
    )


    temperatures = (

        block["cpuTemperature"]

        .to_numpy()
    )


    timestamps = (

        block["timestamp"]

        .to_numpy()
    )


    X = []
    y = []

    current_temperatures = []

    future_temperatures = []

    prediction_timestamps = []


    for i in range(

        lookback,

        len(block) - horizon + 1
    ):


        sequence_start = (
            i - lookback
        )


        current_index = (
            i - 1
        )


        future_index = (

            current_index

            + horizon
        )


        if future_index >= len(block):

            break


        # ------------------------------------
        # Check entire history → future period
        # ------------------------------------

        relevant_times = (

            block["timestamp"]

            .iloc[
                sequence_start:
                future_index + 1
            ]
        )


        gaps = (

            relevant_times

            .diff()

            .dt.total_seconds()

            .dropna()
        )


        if (
            gaps > max_gap_seconds
        ).any():

            continue


        # ------------------------------------
        # Input
        # ------------------------------------

        X.append(

            scaled_features[
                sequence_start:i
            ]
        )


        # ------------------------------------
        # Target
        # ------------------------------------

        current_temp = (

            temperatures[
                current_index
            ]
        )


        future_temp = (

            temperatures[
                future_index
            ]
        )


        delta_temp = (

            future_temp

            - current_temp
        )


        y.append(
            delta_temp
        )


        current_temperatures.append(
            current_temp
        )


        future_temperatures.append(
            future_temp
        )


        prediction_timestamps.append(
            timestamps[
                future_index
            ]
        )


    return (

        np.asarray(X),

        np.asarray(y),

        np.asarray(
            current_temperatures
        ),

        np.asarray(
            future_temperatures
        ),

        np.asarray(
            prediction_timestamps
        )
    )

# %% [markdown]
# # 13. Create datasets from block lists

# %%
def create_dataset_from_blocks(
    blocks,
    scaler
):

    all_X = []
    all_y = []

    all_current = []
    all_future = []

    all_timestamps = []

    all_phases = []
    all_runs = []


    for block in blocks:


        (
            X,
            y,
            current,
            future,
            timestamps

        ) = create_sequences_from_block(

            block=block,

            scaler=scaler,

            lookback=LOOKBACK,

            horizon=HORIZON
        )


        if len(X) == 0:

            continue


        phase = (
            block[
                "phaseGroup"
            ].iloc[0]
        )


        run_name = (
            block[
                "runName"
            ].iloc[0]
        )


        all_X.append(X)

        all_y.append(y)

        all_current.append(
            current
        )

        all_future.append(
            future
        )

        all_timestamps.append(
            timestamps
        )


        all_phases.extend(

            [phase] * len(X)
        )


        all_runs.extend(

            [run_name] * len(X)
        )


    return (

        np.concatenate(all_X),

        np.concatenate(all_y),

        np.concatenate(all_current),

        np.concatenate(all_future),

        np.concatenate(all_timestamps),

        np.asarray(all_phases),

        np.asarray(all_runs)
    )

# %%
(
    X_train,
    y_train,
    train_current,
    train_actual,
    train_timestamps,
    train_phases,
    train_runs

) = create_dataset_from_blocks(

    train_blocks,

    scaler_X
)

# %%
(
    X_val,
    y_val,
    val_current,
    val_actual,
    val_timestamps,
    val_phases,
    val_runs

) = create_dataset_from_blocks(

    val_blocks,

    scaler_X
)

# %%
(
    X_test,
    y_test,
    test_current,
    test_actual,
    test_timestamps,
    test_phases,
    test_runs

) = create_dataset_from_blocks(

    test_blocks,

    scaler_X
)

# %%
print("\nTRAIN")
print("X:", X_train.shape)
print("y:", y_train.shape)

print("\nVALIDATION")
print("X:", X_val.shape)
print("y:", y_val.shape)

print("\nINTERNAL TEST")
print("X:", X_test.shape)
print("y:", y_test.shape)
# Out:
# TRAIN
# X: (15821, 30, 6)
# y: (15821,)
#
# VALIDATION
# X: (3490, 30, 6)
# y: (3490,)
#
# INTERNAL TEST
# X: (4429, 30, 6)
# y: (4429,)

# %% [markdown]
# # 14. Verify Actual Sequence Diversity

# %%
def show_sequence_distribution(
    phases,
    name
):

    print(
        f"\n===== {name} ====="
    )

    print(

        pd.Series(phases)

        .value_counts()
    )

# %%
show_sequence_distribution(
    train_phases,
    "TRAIN"
)

show_sequence_distribution(
    val_phases,
    "VALIDATION"
)

show_sequence_distribution(
    test_phases,
    "INTERNAL TEST"
)
# Out:
# ===== TRAIN =====
# MIXED         6121
# CHAOS         2844
# RAMP          2840
# TRANSITION    2772
# OTHER          829
# COOLING        415
# Name: count, dtype: int64
#
# ===== VALIDATION =====
# MIXED         1421
# CHAOS          473
# TRANSITION     473
# OTHER          473
# RAMP           472
# COOLING        178
# Name: count, dtype: int64
#
# ===== INTERNAL TEST =====
# CHAOS         948
# RAMP          946
# TRANSITION    944
# MIXED         938
# OTHER         475
# COOLING       178
# Name: count, dtype: int64

# %% [markdown]
# # 15. Building the LSTM

# %%
model = Sequential([

    Input(
        shape=(
            LOOKBACK,
            len(FEATURE_COLS)
        )
    ),

    LSTM(
        64,
        return_sequences=True
    ),

    Dropout(0.20),

    LSTM(32),

    Dropout(0.20),

    Dense(
        16,
        activation="relu"
    ),

    Dense(1)
])
# Out:
# E0000 00:00:1783394519.298230    5657 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.compile(

    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001
    ),

    loss="mse",

    metrics=["mae"]
)

# %% [markdown]
# # Part 16: Train

# %%
early_stopping = EarlyStopping(

    monitor="val_loss",

    patience=10,

    restore_best_weights=True,

    verbose=1
)


reduce_lr = ReduceLROnPlateau(

    monitor="val_loss",

    factor=0.5,

    patience=5,

    min_lr=1e-6,

    verbose=1
)


checkpoint = ModelCheckpoint(

    "best_cross_device_lstm.keras",

    monitor="val_loss",

    save_best_only=True,

    verbose=1
)

# %% [markdown]
# Train

# %%
history = model.fit(

    X_train,
    y_train,

    validation_data=(
        X_val,
        y_val
    ),

    epochs=100,

    batch_size=64,

    shuffle=True,

    callbacks=[
        early_stopping,
        reduce_lr,
        checkpoint
    ],

    verbose=1
)
# Out:
# Epoch 1/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 66.6816 - mae: 5.4314
# Epoch 1: val_loss improved from None to 50.15949, saving model to best_cross_device_lstm.keras
#
# Epoch 1: finished saving model to best_cross_device_lstm.keras
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 66.6831 - mae: 5.4309 - val_loss: 50.1595 - val_mae: 4.9721 - learning_rate: 0.0010
# Epoch 2/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 62.5870 - mae: 5.6084
# Epoch 2: val_loss did not improve from 50.15949
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 62.5880 - mae: 5.6083 - val_loss: 52.6281 - val_mae: 5.1994 - learning_rate: 0.0010
# Epoch 3/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 60.8549 - mae: 5.4961
# Epoch 3: val_loss improved from 50.15949 to 49.31575, saving model to best_cross_device_lstm.keras
#
# Epoch 3: finished saving model to best_cross_device_lstm.keras
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - loss: 60.8569 - mae: 5.4959 - val_loss: 49.3158 - val_mae: 4.8616 - learning_rate: 0.0010
# Epoch 4/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 58.3282 - mae: 5.3476
# Epoch 4: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 58.3305 - mae: 5.3477 - val_loss: 52.1236 - val_mae: 4.9250 - learning_rate: 0.0010
# Epoch 5/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 56.9823 - mae: 5.2753
# Epoch 5: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 56.9781 - mae: 5.2748 - val_loss: 53.0710 - val_mae: 5.0099 - learning_rate: 0.0010
# Epoch 6/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 54.9443 - mae: 5.1680
# Epoch 6: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - loss: 54.9423 - mae: 5.1677 - val_loss: 55.1661 - val_mae: 5.1651 - learning_rate: 0.0010
# Epoch 7/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 53.1012 - mae: 5.0432
# Epoch 7: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 53.0991 - mae: 5.0428 - val_loss: 55.2257 - val_mae: 5.0036 - learning_rate: 0.0010
# Epoch 8/100
# 246/248 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 51.3260 - mae: 4.9120
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 8: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - loss: 51.3384 - mae: 4.9120 - val_loss: 60.3360 - val_mae: 5.3776 - learning_rate: 0.0010
# Epoch 9/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 47.7207 - mae: 4.6982
# Epoch 9: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 47.7189 - mae: 4.6982 - val_loss: 57.5958 - val_mae: 5.1054 - learning_rate: 5.0000e-04
# Epoch 10/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 44.7933 - mae: 4.5146
# Epoch 10: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 44.7978 - mae: 4.5150 - val_loss: 54.8911 - val_mae: 4.8421 - learning_rate: 5.0000e-04
# Epoch 11/100
# 246/248 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 43.2574 - mae: 4.4037
# Epoch 11: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - loss: 43.2715 - mae: 4.4023 - val_loss: 55.0412 - val_mae: 4.7463 - learning_rate: 5.0000e-04
# Epoch 12/100
# 247/248 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 41.0455 - mae: 4.2627
# Epoch 12: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 41.0559 - mae: 4.2634 - val_loss: 56.8006 - val_mae: 4.9097 - learning_rate: 5.0000e-04
# Epoch 13/100
# 246/248 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 39.2503 - mae: 4.1516
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 13: val_loss did not improve from 49.31575
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 39.2625 - mae: 4.1500 - val_loss: 59.0473 - val_mae: 4.9018 - learning_rate: 5.0000e-04
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.

# %%
def calculate_metrics(actual, predicted, name):

    mae = mean_absolute_error(
        actual,
        predicted
    )

    rmse = np.sqrt(
        mean_squared_error(
            actual,
            predicted
        )
    )

    r2 = r2_score(
        actual,
        predicted
    )

    print(f"\n===== {name} =====")
    print(f"MAE:  {mae:.3f} °C")
    print(f"RMSE: {rmse:.3f} °C")
    print(f"R²:   {r2:.4f}")

    return {
        "Model": name,
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    }

# %%
    # Load the actual best checkpoint explicitly
best_model = tf.keras.models.load_model(
    "best_cross_device_lstm.keras"
)

# Predict temperature change
test_predicted_delta = (
    best_model.predict(X_test)
    .flatten()
)

# Reconstruct future temperature
test_lstm_predictions = (
    test_current
    + test_predicted_delta
)

# Persistence baseline:
# future temperature = current temperature
test_persistence = test_current.copy()
# Out:
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step

# %%
test_predicted_delta = (

    model.predict(
        X_test
    )

    .flatten()
)
# Out:
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step

# %%
test_lstm_predictions = (

    test_current

    +

    test_predicted_delta
)

# %%
test_persistence = (

    test_current.copy()
)

# %%
internal_baseline = calculate_metrics(

    test_actual,

    test_persistence,

    "Internal Test - Persistence"
)
# Out:
# ===== Internal Test - Persistence =====
# MAE:  5.151 °C
# RMSE: 8.999 °C
# R²:   0.3962

# %%
internal_lstm = calculate_metrics(
    test_actual,
    test_lstm_predictions,
    "Internal Test - LSTM"
)
# Out:
# ===== Internal Test - LSTM =====
# MAE:  6.264 °C
# RMSE: 8.575 °C
# R²:   0.4518

# %%
def evaluate_by_phase(

    actual,
    predicted,
    phases,
    model_name
):

    results = []


    for phase in np.unique(
        phases
    ):

        mask = (
            phases == phase
        )


        if mask.sum() < 10:

            continue


        mae = mean_absolute_error(

            actual[mask],

            predicted[mask]
        )


        rmse = np.sqrt(

            mean_squared_error(

                actual[mask],

                predicted[mask]
            )
        )


        results.append({

            "Model":
                model_name,

            "Phase":
                phase,

            "Samples":
                mask.sum(),

            "MAE":
                mae,

            "RMSE":
                rmse
        })


    return pd.DataFrame(
        results
    )

# %%
lstm_phase_results = evaluate_by_phase(

    test_actual,

    test_lstm_predictions,

    test_phases,

    "LSTM"
)

# %%
baseline_phase_results = evaluate_by_phase(

    test_actual,

    test_persistence,

    test_phases,

    "Persistence"
)

# %%
phase_comparison = pd.concat(

    [
        baseline_phase_results,
        lstm_phase_results
    ],

    ignore_index=True
)

display(
    phase_comparison
)
# Out:
#           Model       Phase  Samples       MAE       RMSE
# 0   Persistence       CHAOS      948  8.199367  12.136114
# 1   Persistence     COOLING      178  1.802247   2.888373
# 2   Persistence       MIXED      938  6.962367  11.188665
# 3   Persistence       OTHER      475  2.690947   3.628878
# 4   Persistence        RAMP      946  2.816913   5.109697
# 5   Persistence  TRANSITION      944  4.496292   8.562040
# 6          LSTM       CHAOS      948  8.415674  10.836225
# 7          LSTM     COOLING      178  7.061297   7.707272
# 8          LSTM       MIXED      938  7.392099   9.827495
# 9          LSTM       OTHER      475  7.104254   7.949555
# 10         LSTM        RAMP      946  3.663215   5.774968
# 11         LSTM  TRANSITION      944  5.016265   7.395053
