# %% [markdown]
# # Part 1: Imports and Configuration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (mean_absolute_error, mean_squared_error, r2_score)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Input, LSTM, Dense, Dropout)

from tensorflow.keras.callbacks import (EarlyStopping, ReduceLROnPlateau, ModelCheckpoint)

import joblib
import random

# %%
SEED = 42
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# Configuration

# %%
# Approximate Sensor interval

SAMPLE_INTERVAL_SECONDS = 2

# Use Previous 60 seconds
LOOKBACK_SECONDS = 60

#Predict 10 seconds into the future
FORECAST_SECONDS = 10

LOOKBACK = LOOKBACK_SECONDS // SAMPLE_INTERVAL_SECONDS
HORIZON = FORECAST_SECONDS // SAMPLE_INTERVAL_SECONDS

print("Lookback samples: ",LOOKBACK)
print("Forecast Horizon samples: ", HORIZON)
# Out:
# Lookback samples:  30
# Forecast Horizon samples:  5

# %% [markdown]
# # Part 2: Loading Datasets

# %%
FILES = {
    "manan": "manan_merged_experiment.csv",
    "prabhsimrat": "prabh_merged_experiment.csv"
    # "sushant":
}

# %%
datasets ={}

for name, path in FILES.items():
    df = pd.read_csv(path)
    df["timestamp"]= pd.to_datetime(df["timestamp"])
    df = df.sort_values("timestamp").reset_index(drop= True)
    df["source"] = name
    datasets[name]= df
    print(name, "-", df.shape)
# Out:
# manan - (14803, 13)
# prabhsimrat - (15365, 13)

# %%
FEATURE_COLS = [
    "cpuUsage",
    "ramUsage",
    "networkConnections",
    "processCount",
    "cpuPackagePower",
    "cpuTemperature"
]

# %%
for name, df in datasets.items():

    print(f"\n===== {name} =====")

    print(
        df[
            [
                "cpuUsage",
                "cpuPackagePower",
                "cpuAverageClock",
                "cpuTemperature"
            ]
        ].describe().loc[
            ["min", "mean", "std", "max"]
        ]
    )
# Out:
# ===== manan =====
#         cpuUsage  cpuPackagePower  cpuAverageClock  cpuTemperature
# min     9.200000         9.600000       403.200000       60.000000
# mean   58.584071        40.438654      2419.553636       86.093292
# std    30.660576        15.644110       471.266927       11.716394
# max   100.000000        66.600000      2973.600000       99.000000
#
# ===== prabhsimrat =====
#         cpuUsage  cpuPackagePower  cpuAverageClock  cpuTemperature
# min     1.000000         6.000000      2810.000000        0.000000
# mean   49.854247        29.637592      3617.252652       87.862786
# std    34.927009        11.036970       287.802921       10.587456
# max   100.000000        50.900000      4492.000000       95.900000

# %% [markdown]
# # Part 3: Cleaning

# %% [markdown]
# After running (after_stress_generator.ipynb)- most of the cleaning is already done

# %%
def clean_run(df):
    df = df.copy()
    # Keep only valid sensor data
    df = df.dropna(subset = FEATURE_COLS)
    df = df.sort_values(
        "timestamp"
    ).reset_index(drop=True)

    return df

# %%
for name in datasets:

    datasets[name] = clean_run(
        datasets[name]
    )

    print(
        name,
        len(datasets[name])
    )
# Out:
# manan 14803
# prabhsimrat 15365

# %% [markdown]
# # Checking Sampling Gaps

# %%
def inspect_time_gaps(df, name):

    gaps = (
        df["timestamp"]
        .diff()
        .dt.total_seconds()
    )

    print(f"\n{name}")

    print(
        "Median interval:",
        gaps.median()
    )

    print(
        "Maximum gap:",
        gaps.max()
    )

    print(
        "Gaps > 5 seconds:",
        (gaps > 5).sum()
    )

# %%
for name, df in datasets.items():

    inspect_time_gaps(
        df,
        name
    )
# Out:
# manan
# Median interval: 2.0298681
# Maximum gap: 4.3050749
# Gaps > 5 seconds: 0
#
# prabhsimrat
# Median interval: 2.02355955
# Maximum gap: 7.0642233
# Gaps > 5 seconds: 1

# %% [markdown]
# # Part 6: Create Balanced Time Blocks

# %%
TRAIN_RUNS = ["manan", "prabhsimrat"]
TEST_RUNS = ["manan", "prabhsimrat"]

# %%
BLOCK_MINUTES = 10

TRAIN_RATIO = 0.7
VAL_RATIO = 0.15
TEST_RATIO = 0.15

# %%
def get_phase_group(mode):

    mode = str(mode).upper()

    if "COOLING" in mode:
        return "COOLING"

    if mode in [
        "INITIAL_IDLE",
        "PRE_EXPERIMENT",
        "POST_EXPERIMENT"
    ]:
        return "IDLE"

    if mode in [
        "RAMP",
        "CHAOS",
        "TRANSITION",
        "MIXED"
    ]:
        return mode

    return "OTHER"

# %%
for name, df in datasets.items():

    df = df.copy()

    df["phaseGroup"] = (
        df["mode"]
        .apply(get_phase_group)
    )

    datasets[name] = df

    print(f"\n===== {name} =====")

    print(
        df["phaseGroup"]
        .value_counts()
    )
# Out:
# ===== manan =====
# phaseGroup
# MIXED         5298
# CHAOS         2658
# RAMP          2656
# TRANSITION    2654
# OTHER          739
# COOLING        739
# IDLE            59
# Name: count, dtype: int64
#
# ===== prabhsimrat =====
# phaseGroup
# IDLE    15365
# Name: count, dtype: int64

# %% [markdown]
# Now Creating Contiguous Blocks

# %%
def create_time_blocks(df, run_name, block_minutes = 10):
    df = df.copy()
    df = df.sort_values("timestamp").reset_index(drop= True)
    all_blocks = []
    block_counter = 0
    
    # --------------------- Processing Each Contiguous Phase Separately----------------------------
    
    phase_change = (df["phaseGroup"]!=df["phaseGroup"].shift())
    
    df["phaseSegment"]= (phase_change.cumsum())
    
    for segment_id, segment in df.groupby("phaseSegment"):
        segment = (segment.sort_values("timestamp").copy())
        phase = (segment["phaseGroup"].iloc[0])
        segment_start = (segment["timestamp"].min())
        
        # Assign 10 minute block number
        elapsed_minutes = (segment["timestamp"] - segment_start).dt.total_seconds() / 60
        
        segment["localBlock"] = (elapsed_minutes // block_minutes).astype(int)
        
        for local_block, block in segment.groupby("localBlock"):
            block = block.copy()
            block["blockId"] = (f"{run_name}"
                                f"{block_counter}")
            block["runName"] = run_name
            all_blocks.append(block)
            block_counter+=1
    
    return all_blocks

# %%
all_blocks = []

for name in TRAIN_RUNS:

    run_blocks = create_time_blocks(

        df=datasets[name],

        run_name=name,

        block_minutes=BLOCK_MINUTES
    )

    all_blocks.extend(
        run_blocks
    )

    print(
        name,
        "blocks:",
        len(run_blocks)
    )
# Out:
# manan blocks: 54
# prabhsimrat blocks: 52

# %% [markdown]
# # 7. Remove Blocks that are too short

# %%
MIN_REQUIRED_SAMPLES = (
    LOOKBACK
    + HORIZON
    + 5
)

# %%
valid_blocks = []

removed_blocks = []

for block in all_blocks:

    if len(block) >= MIN_REQUIRED_SAMPLES:

        valid_blocks.append(block)

    else:

        removed_blocks.append(block)


print(
    "Valid blocks:",
    len(valid_blocks)
)

print(
    "Removed short blocks:",
    len(removed_blocks)
)
# Out:
# Valid blocks: 105
# Removed short blocks: 1

# %%
block_summary = []

for block in valid_blocks:

    block_summary.append({

        "blockId":
            block["blockId"].iloc[0],

        "runName":
            block["runName"].iloc[0],

        "phaseGroup":
            block["phaseGroup"].iloc[0],

        "samples":
            len(block),

        "startTime":
            block["timestamp"].min(),

        "endTime":
            block["timestamp"].max()
    })


block_summary = pd.DataFrame(
    block_summary
)

display(
    block_summary.head(20)
)
# Out:
#     blockId runName phaseGroup  samples                           startTime  \
# 0    manan1   manan       IDLE       59 2026-07-06 02:15:52.811050700+05:30
# 1    manan2   manan       RAMP      296 2026-07-06 02:17:52.834077200+05:30
# 2    manan3   manan       RAMP      295 2026-07-06 02:27:53.976796400+05:30
# 3    manan4   manan       RAMP      295 2026-07-06 02:37:54.652708500+05:30
# 4    manan5   manan       RAMP      296 2026-07-06 02:47:53.518745400+05:30
# 5    manan6   manan       RAMP      292 2026-07-06 02:57:54.002098900+05:30
# 6    manan7   manan       RAMP      296 2026-07-06 03:07:52.939946600+05:30
# 7    manan8   manan       RAMP      296 2026-07-06 03:17:53.410543100+05:30
# 8    manan9   manan       RAMP      295 2026-07-06 03:27:54.375094400+05:30
# 9   manan10   manan       RAMP      295 2026-07-06 03:37:54.764023700+05:30
# 10  manan11   manan    COOLING      147 2026-07-06 03:47:53.510465900+05:30
# 11  manan12   manan      CHAOS      294 2026-07-06 03:52:52.141073800+05:30
# 12  manan13   manan      CHAOS      295 2026-07-06 04:02:52.703170500+05:30
# 13  manan14   manan      CHAOS      296 2026-07-06 04:12:52.462886600+05:30
# 14  manan15   manan      CHAOS      296 2026-07-06 04:22:53.249696800+05:30
# 15  manan16   manan      CHAOS      295    2026-07-06 04:32:53.693924+05:30
# 16  manan17   manan      CHAOS      295    2026-07-06 04:42:52.239192+05:30
# 17  manan18   manan      CHAOS      296    2026-07-06 04:52:52.679917+05:30
# 18  manan19   manan      CHAOS      296 2026-07-06 05:02:52.890880800+05:30
# 19  manan20   manan      CHAOS      295 2026-07-06 05:12:53.889148100+05:30
#
#                                endTime
# 0  2026-07-06 02:17:50.805294900+05:30
# 1  2026-07-06 02:27:51.946574700+05:30
# 2  2026-07-06 02:37:52.628830900+05:30
# 3  2026-07-06 02:47:51.481890400+05:30
# 4  2026-07-06 02:57:51.959968500+05:30
# 5  2026-07-06 03:07:50.885778200+05:30
# 6  2026-07-06 03:17:51.375515200+05:30
# 7  2026-07-06 03:27:52.352622600+05:30
# 8  2026-07-06 03:37:52.734991300+05:30
# 9  2026-07-06 03:47:51.479478400+05:30
# 10 2026-07-06 03:52:50.110064800+05:30
# 11 2026-07-06 04:02:50.677776900+05:30
# 12 2026-07-06 04:12:50.404444100+05:30
# 13 2026-07-06 04:22:51.226516800+05:30
# 14 2026-07-06 04:32:51.664639200+05:30
# 15    2026-07-06 04:42:50.215583+05:30
# 16 2026-07-06 04:52:50.647325800+05:30
# 17 2026-07-06 05:02:50.864456600+05:30
# 18 2026-07-06 05:12:51.854961200+05:30
# 19 2026-07-06 05:22:50.590382100+05:30

# %%
print(
    block_summary[
        "phaseGroup"
    ].value_counts()
)
# Out:
# phaseGroup
# IDLE          53
# MIXED         18
# RAMP           9
# CHAOS          9
# TRANSITION     9
# COOLING        4
# OTHER          3
# Name: count, dtype: int64

# %% [markdown]
# # 8. Split whole blocks into train, validation and internal test

# %%
from sklearn.model_selection import train_test_split

# %%
def split_blocks_balanced(
    block_summary,
    seed=42
):

    train_ids = []
    val_ids = []
    test_ids = []

    # ----------------------------------------
    # Split separately by:
    # device + experiment phase
    # ----------------------------------------

    grouped = block_summary.groupby(
        [
            "runName",
            "phaseGroup"
        ]
    )


    for (
        run_name,
        phase
    ), group in grouped:

        ids = (
            group["blockId"]
            .tolist()
        )


        # Reproducible random order
        rng = np.random.default_rng(
            seed
        )

        rng.shuffle(ids)


        n = len(ids)


        print(
            run_name,
            phase,
            "blocks:",
            n
        )


        # ------------------------------------
        # Very small groups
        # ------------------------------------

        if n == 1:

            train_ids.extend(ids)

            continue


        if n == 2:

            train_ids.append(ids[0])
            val_ids.append(ids[1])

            continue


        # ------------------------------------
        # Normal groups
        # ------------------------------------

        n_train = max(
            1,
            int(round(n * TRAIN_RATIO))
        )

        n_val = max(
            1,
            int(round(n * VAL_RATIO))
        )


        # Ensure at least one test block
        if (
            n_train
            + n_val
            >= n
        ):

            n_train = n - 2
            n_val = 1
            

        train_ids.extend(
            ids[:n_train]
        )


        val_ids.extend(
            ids[
                n_train:
                n_train + n_val
            ]
        )


        test_ids.extend(
            ids[
                n_train + n_val:
            ]
        )


    return (
        train_ids,
        val_ids,
        test_ids
    )

# %%
(
    train_block_ids,
    val_block_ids,
    test_block_ids

) = split_blocks_balanced(
    block_summary,
    seed=SEED
)
# Out:
# manan CHAOS blocks: 9
# manan COOLING blocks: 4
# manan IDLE blocks: 1
# manan MIXED blocks: 18
# manan OTHER blocks: 3
# manan RAMP blocks: 9
# manan TRANSITION blocks: 9
# prabhsimrat IDLE blocks: 52

# %%
print(
    "\nTraining blocks:",
    len(train_block_ids)
)

print(
    "Validation blocks:",
    len(val_block_ids)
)

print(
    "Internal test blocks:",
    len(test_block_ids)
)
# Out:
# Training blocks: 71
# Validation blocks: 16
# Internal test blocks: 18

# %%
block_summary["split"] = (
    "UNASSIGNED"
)

block_summary.loc[

    block_summary["blockId"]
    .isin(train_block_ids),

    "split"

] = "TRAIN"


block_summary.loc[

    block_summary["blockId"]
    .isin(val_block_ids),

    "split"

] = "VALIDATION"


block_summary.loc[

    block_summary["blockId"]
    .isin(test_block_ids),

    "split"

] = "TEST"

# %%
coverage = pd.crosstab(

    block_summary["phaseGroup"],

    block_summary["split"]
)

display(coverage)
# Out:
# split       TEST  TRAIN  VALIDATION
# phaseGroup
# CHAOS          2      6           1
# COOLING        1      2           1
# IDLE           8     37           8
# MIXED          2     13           3
# OTHER          1      1           1
# RAMP           2      6           1
# TRANSITION     2      6           1

# %%
device_coverage = pd.crosstab(

    block_summary["runName"],

    block_summary["split"]
)

display(device_coverage)
# Out:
# split        TEST  TRAIN  VALIDATION
# runName
# manan          10     35           8
# prabhsimrat     8     36           8

# %% [markdown]
# # 10. Converting IDs back to block lists

# %%
train_blocks = []

val_blocks = []

test_blocks = []


for block in valid_blocks:

    block_id = (
        block["blockId"]
        .iloc[0]
    )


    if block_id in train_block_ids:

        train_blocks.append(
            block
        )


    elif block_id in val_block_ids:

        val_blocks.append(
            block
        )


    elif block_id in test_block_ids:

        test_blocks.append(
            block
        )

# %%
print(
    "Train blocks:",
    len(train_blocks)
)

print(
    "Validation blocks:",
    len(val_blocks)
)

print(
    "Internal test blocks:",
    len(test_blocks)
)
# Out:
# Train blocks: 71
# Validation blocks: 16
# Internal test blocks: 18

# %% [markdown]
# # Part 11: Fitting the scaler on traininig blocks only

# %%
scaler_training_data = pd.concat(

    [
        block[FEATURE_COLS]
        for block in train_blocks
    ],

    ignore_index=True
)

# %%
scaler_X = StandardScaler()

scaler_X.fit(
    scaler_training_data
)
# Out:
# StandardScaler()

# %%
joblib.dump(

    scaler_X,

    "cross_device_feature_scaler.pkl"
)

print(
    "Scaler fitted only on training blocks."
)
# Out:
# Scaler fitted only on training blocks.

# %% [markdown]
# # Part 12: Create sequences inside each block

# %%
def create_sequences_from_block(
    block,
    scaler,
    lookback,
    horizon,
    max_gap_seconds=5
):

    block = (
        block
        .sort_values("timestamp")
        .reset_index(drop=True)
        .copy()
    )


    scaled_features = scaler.transform(
        block[FEATURE_COLS]
    )


    temperatures = (

        block["cpuTemperature"]

        .to_numpy()
    )


    timestamps = (

        block["timestamp"]

        .to_numpy()
    )


    X = []
    y = []

    current_temperatures = []

    future_temperatures = []

    prediction_timestamps = []


    for i in range(

        lookback,

        len(block) - horizon + 1
    ):


        sequence_start = (
            i - lookback
        )


        current_index = (
            i - 1
        )


        future_index = (

            current_index

            + horizon
        )


        if future_index >= len(block):

            break


        # ------------------------------------
        # Check entire history → future period
        # ------------------------------------

        relevant_times = (

            block["timestamp"]

            .iloc[
                sequence_start:
                future_index + 1
            ]
        )


        gaps = (

            relevant_times

            .diff()

            .dt.total_seconds()

            .dropna()
        )


        if (
            gaps > max_gap_seconds
        ).any():

            continue


        # ------------------------------------
        # Input
        # ------------------------------------

        X.append(

            scaled_features[
                sequence_start:i
            ]
        )


        # ------------------------------------
        # Target
        # ------------------------------------

        current_temp = (

            temperatures[
                current_index
            ]
        )


        future_temp = (

            temperatures[
                future_index
            ]
        )


        delta_temp = (

            future_temp

            - current_temp
        )


        y.append(
            delta_temp
        )


        current_temperatures.append(
            current_temp
        )


        future_temperatures.append(
            future_temp
        )


        prediction_timestamps.append(
            timestamps[
                future_index
            ]
        )


    return (

        np.asarray(X),

        np.asarray(y),

        np.asarray(
            current_temperatures
        ),

        np.asarray(
            future_temperatures
        ),

        np.asarray(
            prediction_timestamps
        )
    )

# %% [markdown]
# # 13. Create datasets from block lists

# %%
def create_dataset_from_blocks(
    blocks,
    scaler
):

    all_X = []
    all_y = []

    all_current = []
    all_future = []

    all_timestamps = []

    all_phases = []
    all_runs = []


    for block in blocks:


        (
            X,
            y,
            current,
            future,
            timestamps

        ) = create_sequences_from_block(

            block=block,

            scaler=scaler,

            lookback=LOOKBACK,

            horizon=HORIZON
        )


        if len(X) == 0:

            continue


        phase = (
            block[
                "phaseGroup"
            ].iloc[0]
        )


        run_name = (
            block[
                "runName"
            ].iloc[0]
        )


        all_X.append(X)

        all_y.append(y)

        all_current.append(
            current
        )

        all_future.append(
            future
        )

        all_timestamps.append(
            timestamps
        )


        all_phases.extend(

            [phase] * len(X)
        )


        all_runs.extend(

            [run_name] * len(X)
        )


    return (

        np.concatenate(all_X),

        np.concatenate(all_y),

        np.concatenate(all_current),

        np.concatenate(all_future),

        np.concatenate(all_timestamps),

        np.asarray(all_phases),

        np.asarray(all_runs)
    )

# %%
(
    X_train,
    y_train,
    train_current,
    train_actual,
    train_timestamps,
    train_phases,
    train_runs

) = create_dataset_from_blocks(

    train_blocks,

    scaler_X
)

# %%
(
    X_val,
    y_val,
    val_current,
    val_actual,
    val_timestamps,
    val_phases,
    val_runs

) = create_dataset_from_blocks(

    val_blocks,

    scaler_X
)

# %%
(
    X_test,
    y_test,
    test_current,
    test_actual,
    test_timestamps,
    test_phases,
    test_runs

) = create_dataset_from_blocks(

    test_blocks,

    scaler_X
)

# %%
print("\nTRAIN")
print("X:", X_train.shape)
print("y:", y_train.shape)

print("\nVALIDATION")
print("X:", X_val.shape)
print("y:", y_val.shape)

print("\nINTERNAL TEST")
print("X:", X_test.shape)
print("y:", y_test.shape)
# Out:
# TRAIN
# X: (18003, 30, 6)
# y: (18003,)
#
# VALIDATION
# X: (3997, 30, 6)
# y: (3997,)
#
# INTERNAL TEST
# X: (4559, 30, 6)
# y: (4559,)

# %% [markdown]
# # 14. Verify Actual Sequence Diversity

# %%
def show_sequence_distribution(
    phases,
    name
):

    print(
        f"\n===== {name} ====="
    )

    print(

        pd.Series(phases)

        .value_counts()
    )

# %%
show_sequence_distribution(
    train_phases,
    "TRAIN"
)

show_sequence_distribution(
    val_phases,
    "VALIDATION"
)

show_sequence_distribution(
    test_phases,
    "INTERNAL TEST"
)
# Out:
# ===== TRAIN =====
# IDLE          9435
# MIXED         3383
# CHAOS         1569
# RAMP          1566
# TRANSITION    1565
# COOLING        376
# OTHER          109
# Name: count, dtype: int64
#
# ===== VALIDATION =====
# IDLE          2055
# MIXED          784
# RAMP           261
# CHAOS          261
# TRANSITION     261
# OTHER          261
# COOLING        114
# Name: count, dtype: int64
#
# ===== INTERNAL TEST =====
# IDLE          2098
# RAMP           523
# CHAOS          522
# TRANSITION     522
# MIXED          519
# OTHER          262
# COOLING        113
# Name: count, dtype: int64

# %% [markdown]
# # 15. Building the LSTM

# %%
model = Sequential([

    Input(
        shape=(
            LOOKBACK,
            len(FEATURE_COLS)
        )
    ),

    LSTM(
        64,
        return_sequences=True
    ),

    Dropout(0.20),

    LSTM(32),

    Dropout(0.20),

    Dense(
        16,
        activation="relu"
    ),

    Dense(1)
])

# %%
model.compile(

    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001
    ),

    loss="mse",

    metrics=["mae"]
)

# %% [markdown]
# # Part 16: Train

# %%
early_stopping = EarlyStopping(

    monitor="val_loss",

    patience=10,

    restore_best_weights=True,

    verbose=1
)


reduce_lr = ReduceLROnPlateau(

    monitor="val_loss",

    factor=0.5,

    patience=5,

    min_lr=1e-6,

    verbose=1
)


checkpoint = ModelCheckpoint(

    "best_cross_device_lstm.keras",

    monitor="val_loss",

    save_best_only=True,

    verbose=1
)

# %% [markdown]
# Train

# %%
history = model.fit(

    X_train,
    y_train,

    validation_data=(
        X_val,
        y_val
    ),

    epochs=100,

    batch_size=64,

    shuffle=True,

    callbacks=[
        early_stopping,
        reduce_lr,
        checkpoint
    ],

    verbose=1
)
# Out:
# Epoch 1/100
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.8872 - mae: 2.0908
# Epoch 1: val_loss improved from inf to 34.28651, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 23.8708 - mae: 2.0911 - val_loss: 34.2865 - val_mae: 2.3606 - learning_rate: 0.0010
# Epoch 2/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.6950 - mae: 2.1561
# Epoch 2: val_loss improved from 34.28651 to 34.23904, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 23.6638 - mae: 2.1563 - val_loss: 34.2390 - val_mae: 2.3735 - learning_rate: 0.0010
# Epoch 3/100
# 278/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.6539 - mae: 2.1560
# Epoch 3: val_loss did not improve from 34.23904
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 23.6149 - mae: 2.1562 - val_loss: 34.2559 - val_mae: 2.3675 - learning_rate: 0.0010
# Epoch 4/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.5677 - mae: 2.1616
# Epoch 4: val_loss improved from 34.23904 to 34.17805, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 23.5599 - mae: 2.1617 - val_loss: 34.1781 - val_mae: 2.3678 - learning_rate: 0.0010
# Epoch 5/100
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.4770 - mae: 2.1487
# Epoch 5: val_loss improved from 34.17805 to 34.12636, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 23.4613 - mae: 2.1488 - val_loss: 34.1264 - val_mae: 2.3423 - learning_rate: 0.0010
# Epoch 6/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.3045 - mae: 2.1424
# Epoch 6: val_loss improved from 34.12636 to 33.86276, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 23.2967 - mae: 2.1425 - val_loss: 33.8628 - val_mae: 2.3704 - learning_rate: 0.0010
# Epoch 7/100
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.0846 - mae: 2.1530
# Epoch 7: val_loss improved from 33.86276 to 33.55182, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 23.0694 - mae: 2.1531 - val_loss: 33.5518 - val_mae: 2.3455 - learning_rate: 0.0010
# Epoch 8/100
# 278/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.7531 - mae: 2.1471
# Epoch 8: val_loss improved from 33.55182 to 33.00360, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 22.7144 - mae: 2.1473 - val_loss: 33.0036 - val_mae: 2.3384 - learning_rate: 0.0010
# Epoch 9/100
# 278/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.1235 - mae: 2.1272
# Epoch 9: val_loss improved from 33.00360 to 31.82481, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 22.0888 - mae: 2.1274 - val_loss: 31.8248 - val_mae: 2.2501 - learning_rate: 0.0010
# Epoch 10/100
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.5513 - mae: 2.1122
# Epoch 10: val_loss improved from 31.82481 to 31.36587, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 21.5444 - mae: 2.1123 - val_loss: 31.3659 - val_mae: 2.2652 - learning_rate: 0.0010
# Epoch 11/100
# 278/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 20.7924 - mae: 2.0709
# Epoch 11: val_loss improved from 31.36587 to 31.08420, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 20.7623 - mae: 2.0713 - val_loss: 31.0842 - val_mae: 2.3039 - learning_rate: 0.0010
# Epoch 12/100
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.4654 - mae: 2.0659
# Epoch 12: val_loss improved from 31.08420 to 30.36550, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 20.4537 - mae: 2.0661 - val_loss: 30.3655 - val_mae: 2.3153 - learning_rate: 0.0010
# Epoch 13/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 20.0301 - mae: 2.0677
# Epoch 13: val_loss improved from 30.36550 to 30.05676, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 20.0087 - mae: 2.0679 - val_loss: 30.0568 - val_mae: 2.2850 - learning_rate: 0.0010
# Epoch 14/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.7667 - mae: 2.0474
# Epoch 14: val_loss improved from 30.05676 to 29.43428, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 19.7462 - mae: 2.0476 - val_loss: 29.4343 - val_mae: 2.2731 - learning_rate: 0.0010
# Epoch 15/100
# 280/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.4321 - mae: 2.0525
# Epoch 15: val_loss did not improve from 29.43428
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 19.4166 - mae: 2.0526 - val_loss: 29.5139 - val_mae: 2.3080 - learning_rate: 0.0010
# Epoch 16/100
# 277/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.1552 - mae: 2.0368
# Epoch 16: val_loss improved from 29.43428 to 29.10029, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 19.1256 - mae: 2.0373 - val_loss: 29.1003 - val_mae: 2.2831 - learning_rate: 0.0010
# Epoch 17/100
# 280/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 18.6660 - mae: 2.0271
# Epoch 17: val_loss improved from 29.10029 to 28.93484, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 18.6522 - mae: 2.0273 - val_loss: 28.9348 - val_mae: 2.3114 - learning_rate: 0.0010
# Epoch 18/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.3382 - mae: 2.0118
# Epoch 18: val_loss improved from 28.93484 to 28.53750, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 18.3221 - mae: 2.0121 - val_loss: 28.5375 - val_mae: 2.3004 - learning_rate: 0.0010
# Epoch 19/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.9915 - mae: 1.9964
# Epoch 19: val_loss improved from 28.53750 to 28.23690, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 17.9736 - mae: 1.9967 - val_loss: 28.2369 - val_mae: 2.2900 - learning_rate: 0.0010
# Epoch 20/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.4910 - mae: 1.9812
# Epoch 20: val_loss improved from 28.23690 to 28.10432, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 17.4781 - mae: 1.9816 - val_loss: 28.1043 - val_mae: 2.2912 - learning_rate: 0.0010
# Epoch 21/100
# 277/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.3994 - mae: 1.9666
# Epoch 21: val_loss did not improve from 28.10432
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 17.3794 - mae: 1.9674 - val_loss: 28.4064 - val_mae: 2.2875 - learning_rate: 0.0010
# Epoch 22/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.3998 - mae: 1.9676
# Epoch 22: val_loss improved from 28.10432 to 27.73474, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 17.3834 - mae: 1.9679 - val_loss: 27.7347 - val_mae: 2.2900 - learning_rate: 0.0010
# Epoch 23/100
# 277/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.8616 - mae: 1.9550
# Epoch 23: val_loss improved from 27.73474 to 27.70005, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 16.8399 - mae: 1.9553 - val_loss: 27.7001 - val_mae: 2.3049 - learning_rate: 0.0010
# Epoch 24/100
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.8103 - mae: 1.9482
# Epoch 24: val_loss did not improve from 27.70005
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 16.8039 - mae: 1.9484 - val_loss: 27.9546 - val_mae: 2.3340 - learning_rate: 0.0010
# Epoch 25/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 16.9273 - mae: 1.9460
# Epoch 25: val_loss improved from 27.70005 to 27.17776, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 16.9115 - mae: 1.9462 - val_loss: 27.1778 - val_mae: 2.2491 - learning_rate: 0.0010
# Epoch 26/100
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.3501 - mae: 1.9232
# Epoch 26: val_loss did not improve from 27.17776
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 16.3433 - mae: 1.9234 - val_loss: 27.4442 - val_mae: 2.2660 - learning_rate: 0.0010
# Epoch 27/100
# 278/282 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 16.2392 - mae: 1.9151
# Epoch 27: val_loss did not improve from 27.17776
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 16.2224 - mae: 1.9156 - val_loss: 27.3415 - val_mae: 2.2713 - learning_rate: 0.0010
# Epoch 28/100
# 278/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.2208 - mae: 1.8979
# Epoch 28: val_loss did not improve from 27.17776
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 16.2046 - mae: 1.8986 - val_loss: 27.2710 - val_mae: 2.2916 - learning_rate: 0.0010
# Epoch 29/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.1488 - mae: 1.9213
# Epoch 29: val_loss improved from 27.17776 to 27.12809, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 16.1319 - mae: 1.9213 - val_loss: 27.1281 - val_mae: 2.2551 - learning_rate: 0.0010
# Epoch 30/100
# 280/282 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 15.9241 - mae: 1.9008
# Epoch 30: val_loss improved from 27.12809 to 26.97013, saving model to best_cross_device_lstm.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 15.9157 - mae: 1.9011 - val_loss: 26.9701 - val_mae: 2.2133 - learning_rate: 0.0010
# Epoch 31/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 15.3045 - mae: 1.8636
# Epoch 31: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 15.2946 - mae: 1.8641 - val_loss: 27.5543 - val_mae: 2.3153 - learning_rate: 0.0010
# Epoch 32/100
# 277/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.3725 - mae: 1.8713
# Epoch 32: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 15.3524 - mae: 1.8717 - val_loss: 27.6116 - val_mae: 2.3396 - learning_rate: 0.0010
# Epoch 33/100
# 280/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.5477 - mae: 1.8755
# Epoch 33: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 15.5395 - mae: 1.8758 - val_loss: 27.5363 - val_mae: 2.3053 - learning_rate: 0.0010
# Epoch 34/100
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15.7250 - mae: 1.8865
# Epoch 34: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 15.7168 - mae: 1.8865 - val_loss: 27.7596 - val_mae: 2.2935 - learning_rate: 0.0010
# Epoch 35/100
# 279/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15.2681 - mae: 1.8617
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 35: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 15.2530 - mae: 1.8619 - val_loss: 27.8712 - val_mae: 2.3483 - learning_rate: 0.0010
# Epoch 36/100
# 280/282 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 14.7645 - mae: 1.8181
# Epoch 36: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 14.7529 - mae: 1.8183 - val_loss: 28.5985 - val_mae: 2.3771 - learning_rate: 5.0000e-04
# Epoch 37/100
# 280/282 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 14.3287 - mae: 1.8049
# Epoch 37: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 14.3184 - mae: 1.8052 - val_loss: 27.9515 - val_mae: 2.3649 - learning_rate: 5.0000e-04
# Epoch 38/100
# 278/282 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.2895 - mae: 1.7960
# Epoch 38: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 14.2705 - mae: 1.7961 - val_loss: 28.2758 - val_mae: 2.3781 - learning_rate: 5.0000e-04
# Epoch 39/100
# 280/282 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 14.0850 - mae: 1.7869
# Epoch 39: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 14.0734 - mae: 1.7870 - val_loss: 28.2921 - val_mae: 2.3643 - learning_rate: 5.0000e-04
# Epoch 40/100
# 280/282 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.0270 - mae: 1.7651
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 40: val_loss did not improve from 26.97013
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 14.0150 - mae: 1.7652 - val_loss: 29.7737 - val_mae: 2.4557 - learning_rate: 5.0000e-04
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.

# %%
def calculate_metrics(actual, predicted, name):

    mae = mean_absolute_error(
        actual,
        predicted
    )

    rmse = np.sqrt(
        mean_squared_error(
            actual,
            predicted
        )
    )

    r2 = r2_score(
        actual,
        predicted
    )

    print(f"\n===== {name} =====")
    print(f"MAE:  {mae:.3f} °C")
    print(f"RMSE: {rmse:.3f} °C")
    print(f"R²:   {r2:.4f}")

    return {
        "Model": name,
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    }

# %%
    # Load the actual best checkpoint explicitly
best_model = tf.keras.models.load_model(
    "best_cross_device_lstm.keras"
)

# Predict temperature change
test_predicted_delta = (
    best_model.predict(X_test)
    .flatten()
)

# Reconstruct future temperature
test_lstm_predictions = (
    test_current
    + test_predicted_delta
)

# Persistence baseline:
# future temperature = current temperature
test_persistence = test_current.copy()
# Out:
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
test_predicted_delta = (

    model.predict(
        X_test
    )

    .flatten()
)
# Out:
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
test_lstm_predictions = (

    test_current

    +

    test_predicted_delta
)

# %%
test_persistence = (

    test_current.copy()
)

# %%
internal_baseline = calculate_metrics(

    test_actual,

    test_persistence,

    "Internal Test - Persistence"
)
# Out:
# ===== Internal Test - Persistence =====
# MAE:  1.990 °C
# RMSE: 4.990 °C
# R²:   0.7927

# %%
internal_lstm = calculate_metrics(
    test_actual,
    test_lstm_predictions,
    "Internal Test - LSTM"
)
# Out:
# ===== Internal Test - LSTM =====
# MAE:  2.120 °C
# RMSE: 4.832 °C
# R²:   0.8056

# %%
def evaluate_by_phase(

    actual,
    predicted,
    phases,
    model_name
):

    results = []


    for phase in np.unique(
        phases
    ):

        mask = (
            phases == phase
        )


        if mask.sum() < 10:

            continue


        mae = mean_absolute_error(

            actual[mask],

            predicted[mask]
        )


        rmse = np.sqrt(

            mean_squared_error(

                actual[mask],

                predicted[mask]
            )
        )


        results.append({

            "Model":
                model_name,

            "Phase":
                phase,

            "Samples":
                mask.sum(),

            "MAE":
                mae,

            "RMSE":
                rmse
        })


    return pd.DataFrame(
        results
    )

# %%
lstm_phase_results = evaluate_by_phase(

    test_actual,

    test_lstm_predictions,

    test_phases,

    "LSTM"
)

# %%
baseline_phase_results = evaluate_by_phase(

    test_actual,

    test_persistence,

    test_phases,

    "Persistence"
)

# %%
phase_comparison = pd.concat(

    [
        baseline_phase_results,
        lstm_phase_results
    ],

    ignore_index=True
)

display(
    phase_comparison
)
# Out:
#           Model       Phase  Samples       MAE      RMSE
# 0   Persistence       CHAOS      522  3.113027  5.968147
# 1   Persistence     COOLING      113  2.566372  3.499684
# 2   Persistence        IDLE     2098  1.229647  5.307795
# 3   Persistence       MIXED      519  2.963391  5.500394
# 4   Persistence       OTHER      262  2.316794  3.061083
# 5   Persistence        RAMP      523  2.395793  3.773967
# 6   Persistence  TRANSITION      522  2.256705  4.110075
# 7          LSTM       CHAOS      522  3.245273  5.916851
# 8          LSTM     COOLING      113  2.104526  2.592430
# 9          LSTM        IDLE     2098  1.332819  4.805301
# 10         LSTM       MIXED      519  3.233251  5.663735
# 11         LSTM       OTHER      262  2.412299  3.458204
# 12         LSTM        RAMP      523  2.840040  4.718800
# 13         LSTM  TRANSITION      522  2.184737  3.799145
