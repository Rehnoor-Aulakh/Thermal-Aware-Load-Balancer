# %% [markdown]
# # Tuned for 20s Horizon — Summary of Changes (CNN+LSTM Experiment)
#
# This version implements a controlled experiment where the recurrent layer is switched to an **LSTM**.
#
# 1. **Architecture**: Replaced `GRU` with `LSTM(BEST_UNITS, recurrent_dropout=0.1, kernel_regularizer=l2(1e-4))`.
# 2. **Lookback window**: 40s (20 samples).
# 3. **Regularization**: Recurrent dropout and L2 weight decay.
# 4. **Bug fixes**: Corrected checkpoint referencing and ensured evaluation uses the best saved model weights.

# %% [markdown]
# # Part 1: Imports and Configuration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (mean_absolute_error, mean_squared_error, r2_score)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Input, LSTM, Dense, Dropout)

from tensorflow.keras.callbacks import (EarlyStopping, ReduceLROnPlateau, ModelCheckpoint)

import joblib
import random

# %%
SEED = 42
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# Configuration

# %%
# Approximate Sensor interval
SAMPLE_INTERVAL_SECONDS = 2

# TUNED: shortened from 60s to 40s.
# For a short 20s forecast horizon, a 60s (30-sample) lookback carries a lot of
# older, less-relevant history that mostly adds noise/variance to the LSTM's
# hidden state. A 40s (20-sample) window still captures the recent
# heating/cooling trend (slope) needed to predict 20s ahead, while giving the
# model fewer, more relevant timesteps to learn from -> less overfitting and
# faster training.
LOOKBACK_SECONDS = 40

# Predict 20 seconds into the future
FORECAST_SECONDS = 10

LOOKBACK = LOOKBACK_SECONDS // SAMPLE_INTERVAL_SECONDS
HORIZON = FORECAST_SECONDS // SAMPLE_INTERVAL_SECONDS

print("Lookback samples: ", LOOKBACK)
print("Forecast Horizon samples: ", HORIZON)
# Out:
# Lookback samples:  20
# Forecast Horizon samples:  5

# %% [markdown]
# # Part 2: Loading Datasets

# %%
FILES = {
    "prabhsimrat": "prabh_merged_experiment.csv",
    "manan": "manan_merged_experiment.csv",
    "gursimar": "gursimar_merged_experiment.csv",
    "sushant": "sushant2_merged_experiment.csv",
    "gurvivek": "gurvivek_merged_experiment.csv"
}

# %%
datasets ={}

for name, path in FILES.items():
    df = pd.read_csv(path)
    df["timestamp"]= pd.to_datetime(df["timestamp"])
    df["targetLoad"] = df["targetLoad"].fillna(0)
    df = df.sort_values("timestamp").reset_index(drop= True)
    df["source"] = name
    datasets[name]= df
    print(name, "-", df.shape)
# Out:
# prabhsimrat - (14291, 29)
# manan - (15275, 29)
# gursimar - (14621, 29)
# sushant - (14133, 29)
# gurvivek - (15391, 29)

# %%
FEATURE_COLS = [
    "cpuUsage",
    "cpuPackagePower",
    "gpuCoreTemperature",
    "gpuHotspotTemperature",
    "cpuEfficiencyAverageClock",
    "targetLoad",
    "cpuTemperature"
]

# %%
for name, df in datasets.items():

    print(f"\n===== {name} =====")

    print(
        df[
            [
                "cpuUsage",
                "cpuPackagePower",
                "cpuAverageClock",
                "cpuTemperature"
            ]
        ].describe().loc[
            ["min", "mean", "std", "max"]
        ]
    )
# Out:
# ===== prabhsimrat =====
#         cpuUsage  cpuPackagePower  cpuAverageClock  cpuTemperature
# min     0.600000         0.500000      2005.000000       53.300000
# mean   48.496858        32.546904      3672.292212       84.164054
# std    34.828684        15.110058       351.956097       14.467376
# max   100.000000        63.500000      4517.000000       96.300000
#
# ===== manan =====
#         cpuUsage  cpuPackagePower  cpuAverageClock  cpuTemperature
# min     1.000000         7.400000      1096.200000       56.000000
# mean   53.342507        37.440537      2687.528492       80.644452
# std    32.784520        18.687431       676.848676       14.234102
# max   100.000000        66.500000      3225.900000       99.000000
#
# ===== gursimar =====
#         cpuUsage  cpuPackagePower  cpuAverageClock  cpuTemperature
# min     0.500000         4.200000      1300.000000       40.400000
# mean   51.469482        30.899815      3474.685521       83.150085
# std    34.245191        15.380098       581.144890       15.694732
# max   100.000000        56.800000      3992.000000      108.300000
#
# ===== sushant =====
#         cpuUsage  cpuPackagePower  cpuAverageClock  cpuTemperature
# min     0.300000         3.500000       401.700000       56.000000
# mean   55.987129        19.038520      2753.714023       86.133659
# std    32.156915         7.965482       414.094800       12.644127
# max   100.000000        36.900000      4519.400000      100.000000
#
# ===== gurvivek =====
#         cpuUsage  cpuPackagePower  cpuAverageClock  cpuTemperature
# min     0.700000         3.000000       388.000000       54.100000
# mean   45.732831        28.012975      3335.451822       86.693434
# std    34.969665        12.129977       196.440088       14.587663
# max   100.000000        58.200000      4142.000000      100.900000

# %% [markdown]
# # Part 3: Cleaning

# %% [markdown]
# After running (after_stress_generator.ipynb)- most of the cleaning is already done

# %%
def clean_run(df):
    df = df.copy()
    # Keep only valid sensor data
    df = df.dropna(subset=FEATURE_COLS)

    # ---- TUNED: additional data cleaning ----
    # Drop physically implausible sensor glitches. A single bad reading (e.g. a
    # negative/zero temperature or >100% usage spike) can inject a large,
    # meaningless dT into the target and encourage the model to chase noise.
    df = df[(df["cpuTemperature"] > 0) & (df["cpuTemperature"] < 110)]
    df = df[(df["cpuUsage"] >= 0) & (df["cpuUsage"] <= 100)]

    # Winsorize (clip, don't drop) the remaining noisy features to their
    # 1st-99th percentile. Clipping instead of dropping preserves the
    # contiguous time index that the sequence builder relies on.
    for col in ["ramUsage", "networkConnections", "processCount", "cpuPackagePower"]:
        lower = df[col].quantile(0.01)
        upper = df[col].quantile(0.99)
        df[col] = df[col].clip(lower, upper)

    df = df.sort_values(
        "timestamp"
    ).reset_index(drop=True)

    return df

# %%
for name in datasets:

    datasets[name] = clean_run(
        datasets[name]
    )

    print(
        name,
        len(datasets[name])
    )
# Out:
# prabhsimrat 14291
# manan 15275
# gursimar 14621
# sushant 14133
# gurvivek 15391

# %% [markdown]
# # Checking Sampling Gaps

# %%
def inspect_time_gaps(df, name):

    gaps = (
        df["timestamp"]
        .diff()
        .dt.total_seconds()
    )

    print(f"\n{name}")

    print(
        "Median interval:",
        gaps.median()
    )

    print(
        "Maximum gap:",
        gaps.max()
    )

    print(
        "Gaps > 5 seconds:",
        (gaps > 5).sum()
    )

# %%
for name, df in datasets.items():

    inspect_time_gaps(
        df,
        name
    )
# Out:
# prabhsimrat
# Median interval: 2.0221316
# Maximum gap: 15.3296387
# Gaps > 5 seconds: 1
#
# manan
# Median interval: 2.029322
# Maximum gap: 2.77304
# Gaps > 5 seconds: 0
#
# gursimar
# Median interval: 2.0232760499999998
# Maximum gap: 5.223701
# Gaps > 5 seconds: 1
#
# sushant
# Median interval: 2.04348185
# Maximum gap: 4.4327946
# Gaps > 5 seconds: 0
#
# gurvivek
# Median interval: 2.0280052499999996
# Maximum gap: 287.5861578
# Gaps > 5 seconds: 2

# %% [markdown]
# # Part 6: Create Balanced Time Blocks

# %%
TRAIN_RUNS = ["prabhsimrat", "manan", "gursimar", "sushant", "gurvivek"]
TEST_RUNS = ["prabhsimrat", "manan", "gursimar", "sushant", "gurvivek"]

# %%
BLOCK_MINUTES = 10

TRAIN_RATIO = 0.7
VAL_RATIO = 0.15
TEST_RATIO = 0.15

# %%
def get_phase_group(mode):

    mode = str(mode).upper()

    if "COOLING" in mode:
        return "COOLING"

    if mode in [
        "INITIAL_IDLE",
        "PRE_EXPERIMENT",
        "POST_EXPERIMENT"
    ]:
        return "IDLE"

    if mode in [
        "RAMP",
        "CHAOS",
        "TRANSITION",
        "MIXED"
    ]:
        return mode

    return "OTHER"

# %%
for name, df in datasets.items():

    df = df.copy()

    df["phaseGroup"] = (
        df["mode"]
        .apply(get_phase_group)
    )

    datasets[name] = df

    print(f"\n===== {name} =====")

    print(
        df["phaseGroup"]
        .value_counts()
    )
# Out:
# ===== prabhsimrat =====
# phaseGroup
# MIXED         4374
# OTHER         2250
# CHAOS         2192
# RAMP          2190
# TRANSITION    2187
# COOLING       1038
# IDLE            60
# Name: count, dtype: int64
#
# ===== manan =====
# phaseGroup
# MIXED         4365
# OTHER         2971
# CHAOS         2188
# TRANSITION    2185
# RAMP          2183
# COOLING       1325
# IDLE            58
# Name: count, dtype: int64
#
# ===== gursimar =====
# phaseGroup
# MIXED         4378
# OTHER         2292
# CHAOS         2188
# TRANSITION    2186
# RAMP          2184
# COOLING       1334
# IDLE            59
# Name: count, dtype: int64
#
# ===== sushant =====
# phaseGroup
# MIXED         4316
# OTHER         2194
# CHAOS         2168
# RAMP          2163
# TRANSITION    2161
# COOLING       1078
# IDLE            53
# Name: count, dtype: int64
#
# ===== gurvivek =====
# phaseGroup
# MIXED         4365
# OTHER         3084
# RAMP          2186
# CHAOS         2186
# TRANSITION    2180
# COOLING       1331
# IDLE            59
# Name: count, dtype: int64

# %% [markdown]
# Now Creating Contiguous Blocks

# %%
def create_time_blocks(df, run_name, block_minutes = 10):
    df = df.copy()
    df = df.sort_values("timestamp").reset_index(drop= True)
    all_blocks = []
    block_counter = 0

    # --------------------- Processing Each Contiguous Phase Separately----------------------------

    phase_change = (df["phaseGroup"]!=df["phaseGroup"].shift())

    df["phaseSegment"]= (phase_change.cumsum())

    for segment_id, segment in df.groupby("phaseSegment"):
        segment = (segment.sort_values("timestamp").copy())
        phase = (segment["phaseGroup"].iloc[0])
        segment_start = (segment["timestamp"].min())

        # Assign 10 minute block number
        elapsed_minutes = (segment["timestamp"] - segment_start).dt.total_seconds() / 60

        segment["localBlock"] = (elapsed_minutes // block_minutes).astype(int)

        for local_block, block in segment.groupby("localBlock"):
            block = block.copy()
            block["blockId"] = (f"{run_name}"
                                f"{block_counter}")
            block["runName"] = run_name
            all_blocks.append(block)
            block_counter+=1

    return all_blocks

# %%
all_blocks = []

for name in TRAIN_RUNS:

    run_blocks = create_time_blocks(

        df=datasets[name],

        run_name=name,

        block_minutes=BLOCK_MINUTES
    )

    all_blocks.extend(
        run_blocks
    )

    print(
        name,
        "blocks:",
        len(run_blocks)
    )
# Out:
# prabhsimrat blocks: 57
# manan blocks: 62
# gursimar blocks: 59
# sushant blocks: 58
# gurvivek blocks: 61

# %% [markdown]
# # 7. Remove Blocks that are too short

# %%
MIN_REQUIRED_SAMPLES = (
    LOOKBACK
    + HORIZON
    + 5
)

# %%
valid_blocks = []

removed_blocks = []

for block in all_blocks:

    if len(block) >= MIN_REQUIRED_SAMPLES:

        valid_blocks.append(block)

    else:

        removed_blocks.append(block)


print(
    "Valid blocks:",
    len(valid_blocks)
)

print(
    "Removed short blocks:",
    len(removed_blocks)
)
# Out:
# Valid blocks: 293
# Removed short blocks: 4

# %%
block_summary = []

for block in valid_blocks:

    block_summary.append({

        "blockId":
            block["blockId"].iloc[0],

        "runName":
            block["runName"].iloc[0],

        "phaseGroup":
            block["phaseGroup"].iloc[0],

        "samples":
            len(block),

        "startTime":
            block["timestamp"].min(),

        "endTime":
            block["timestamp"].max()
    })


block_summary = pd.DataFrame(
    block_summary
)

display(
    block_summary.head(20)
)
# Out:
#           blockId      runName phaseGroup  samples  \
# 0    prabhsimrat1  prabhsimrat       IDLE       60
# 1    prabhsimrat2  prabhsimrat       RAMP      297
# 2    prabhsimrat3  prabhsimrat       RAMP      294
# 3    prabhsimrat4  prabhsimrat       RAMP      297
# 4    prabhsimrat5  prabhsimrat       RAMP      297
# 5    prabhsimrat6  prabhsimrat       RAMP      294
# 6    prabhsimrat7  prabhsimrat       RAMP      297
# 7    prabhsimrat8  prabhsimrat       RAMP      297
# 8    prabhsimrat9  prabhsimrat       RAMP      117
# 9   prabhsimrat10  prabhsimrat    COOLING      149
# 10  prabhsimrat11  prabhsimrat      OTHER      295
# 11  prabhsimrat12  prabhsimrat      OTHER      297
# 12  prabhsimrat13  prabhsimrat      OTHER      293
# 13  prabhsimrat14  prabhsimrat    COOLING      148
# 14  prabhsimrat15  prabhsimrat      CHAOS      295
# 15  prabhsimrat16  prabhsimrat      CHAOS      295
# 16  prabhsimrat17  prabhsimrat      CHAOS      297
# 17  prabhsimrat18  prabhsimrat      CHAOS      296
# 18  prabhsimrat19  prabhsimrat      CHAOS      297
# 19  prabhsimrat20  prabhsimrat      CHAOS      297
#
#                              startTime                             endTime
# 0  2026-07-13 01:46:21.516468900+05:30 2026-07-13 01:48:20.954834300+05:30
# 1  2026-07-13 01:48:22.976551300+05:30 2026-07-13 01:58:21.543317200+05:30
# 2     2026-07-13 01:58:23.563991+05:30 2026-07-13 02:08:21.667127800+05:30
# 3  2026-07-13 02:08:23.693350100+05:30 2026-07-13 02:18:22.170001900+05:30
# 4  2026-07-13 02:18:24.190197800+05:30 2026-07-13 02:28:22.354821300+05:30
# 5  2026-07-13 02:28:24.373413100+05:30 2026-07-13 02:38:21.209319500+05:30
# 6  2026-07-13 02:38:23.234455900+05:30 2026-07-13 02:48:22.411768600+05:30
# 7  2026-07-13 02:48:24.430841100+05:30 2026-07-13 02:58:22.673117500+05:30
# 8  2026-07-13 02:58:24.693306400+05:30 2026-07-13 03:02:19.217204900+05:30
# 9  2026-07-13 03:02:21.235932100+05:30 2026-07-13 03:07:20.273973200+05:30
# 10 2026-07-13 03:07:22.296299400+05:30 2026-07-13 03:17:20.393531500+05:30
# 11 2026-07-13 03:17:22.416440800+05:30 2026-07-13 03:27:21.429614100+05:30
# 12 2026-07-13 03:27:23.456711200+05:30 2026-07-13 03:37:20.356565400+05:30
# 13 2026-07-13 03:37:22.389310800+05:30 2026-07-13 03:42:19.412005700+05:30
# 14 2026-07-13 03:42:21.432184300+05:30 2026-07-13 03:52:19.828367700+05:30
# 15 2026-07-13 03:52:21.848252600+05:30 2026-07-13 04:02:20.064101500+05:30
# 16 2026-07-13 04:02:22.083295400+05:30 2026-07-13 04:12:20.469790200+05:30
# 17 2026-07-13 04:12:22.488575500+05:30 2026-07-13 04:22:19.749138600+05:30
# 18    2026-07-13 04:22:21.770715+05:30 2026-07-13 04:32:19.977019900+05:30
# 19 2026-07-13 04:32:21.998219500+05:30 2026-07-13 04:42:20.757555500+05:30

# %%
print(
    block_summary[
        "phaseGroup"
    ].value_counts()
)
# Out:
# phaseGroup
# MIXED         75
# OTHER         54
# RAMP          40
# CHAOS         40
# TRANSITION    40
# COOLING       39
# IDLE           5
# Name: count, dtype: int64

# %% [markdown]
# # 8. Split whole blocks into train, validation and internal test

# %%
from sklearn.model_selection import train_test_split

# %%
def split_blocks_balanced(
    block_summary,
    seed=42
):

    train_ids = []
    val_ids = []
    test_ids = []

    # ----------------------------------------
    # Split separately by:
    # device + experiment phase
    # ----------------------------------------

    grouped = block_summary.groupby(
        [
            "runName",
            "phaseGroup"
        ]
    )


    for (
        run_name,
        phase
    ), group in grouped:

        ids = (
            group["blockId"]
            .tolist()
        )


        # Reproducible random order
        rng = np.random.default_rng(
            seed
        )

        rng.shuffle(ids)


        n = len(ids)


        print(
            run_name,
            phase,
            "blocks:",
            n
        )


        # ------------------------------------
        # Very small groups
        # ------------------------------------

        if n == 1:

            train_ids.extend(ids)

            continue


        if n == 2:

            train_ids.append(ids[0])
            val_ids.append(ids[1])

            continue


        # ------------------------------------
        # Normal groups
        # ------------------------------------

        n_train = max(
            1,
            int(round(n * TRAIN_RATIO))
        )

        n_val = max(
            1,
            int(round(n * VAL_RATIO))
        )


        # Ensure at least one test block
        if (
            n_train
            + n_val
            >= n
        ):

            n_train = n - 2
            n_val = 1


        train_ids.extend(
            ids[:n_train]
        )


        val_ids.extend(
            ids[
                n_train:
                n_train + n_val
            ]
        )


        test_ids.extend(
            ids[
                n_train + n_val:
            ]
        )


    return (
        train_ids,
        val_ids,
        test_ids
    )

# %%
(
    train_block_ids,
    val_block_ids,
    test_block_ids

) = split_blocks_balanced(
    block_summary,
    seed=SEED
)
# Out:
# gursimar CHAOS blocks: 8
# gursimar COOLING blocks: 8
# gursimar IDLE blocks: 1
# gursimar MIXED blocks: 15
# gursimar OTHER blocks: 11
# gursimar RAMP blocks: 8
# gursimar TRANSITION blocks: 8
# gurvivek CHAOS blocks: 8
# gurvivek COOLING blocks: 8
# gurvivek IDLE blocks: 1
# gurvivek MIXED blocks: 15
# gurvivek OTHER blocks: 13
# gurvivek RAMP blocks: 8
# gurvivek TRANSITION blocks: 8
# manan CHAOS blocks: 8
# manan COOLING blocks: 8
# manan IDLE blocks: 1
# manan MIXED blocks: 15
# manan OTHER blocks: 12
# manan RAMP blocks: 8
# manan TRANSITION blocks: 8
# prabhsimrat CHAOS blocks: 8
# prabhsimrat COOLING blocks: 7
# prabhsimrat IDLE blocks: 1
# prabhsimrat MIXED blocks: 15
# prabhsimrat OTHER blocks: 9
# prabhsimrat RAMP blocks: 8
# prabhsimrat TRANSITION blocks: 8
# sushant CHAOS blocks: 8
# sushant COOLING blocks: 8
# sushant IDLE blocks: 1
# sushant MIXED blocks: 15
# sushant OTHER blocks: 9
# sushant RAMP blocks: 8
# sushant TRANSITION blocks: 8

# %%
print(
    "\nTraining blocks:",
    len(train_block_ids)
)

print(
    "Validation blocks:",
    len(val_block_ids)
)

print(
    "Internal test blocks:",
    len(test_block_ids)
)
# Out:
# Training blocks: 211
# Validation blocks: 38
# Internal test blocks: 44

# %%
block_summary["split"] = (
    "UNASSIGNED"
)

block_summary.loc[

    block_summary["blockId"]
    .isin(train_block_ids),

    "split"

] = "TRAIN"


block_summary.loc[

    block_summary["blockId"]
    .isin(val_block_ids),

    "split"

] = "VALIDATION"


block_summary.loc[

    block_summary["blockId"]
    .isin(test_block_ids),

    "split"

] = "TEST"

# %%
coverage = pd.crosstab(

    block_summary["phaseGroup"],

    block_summary["split"]
)

display(coverage)
# Out:
# split       TEST  TRAIN  VALIDATION
# phaseGroup
# CHAOS          5     30           5
# COOLING        5     29           5
# IDLE           0      5           0
# MIXED         15     50          10
# OTHER          9     37           8
# RAMP           5     30           5
# TRANSITION     5     30           5

# %%
device_coverage = pd.crosstab(

    block_summary["runName"],

    block_summary["split"]
)

display(device_coverage)
# Out:
# split        TEST  TRAIN  VALIDATION
# runName
# gursimar        8     43           8
# gurvivek        9     44           8
# manan           9     43           8
# prabhsimrat     9     40           7
# sushant         9     41           7

# %% [markdown]
# # 10. Converting IDs back to block lists

# %%
train_blocks = []

val_blocks = []

test_blocks = []


for block in valid_blocks:

    block_id = (
        block["blockId"]
        .iloc[0]
    )


    if block_id in train_block_ids:

        train_blocks.append(
            block
        )


    elif block_id in val_block_ids:

        val_blocks.append(
            block
        )


    elif block_id in test_block_ids:

        test_blocks.append(
            block
        )

# %%
print(
    "Train blocks:",
    len(train_blocks)
)

print(
    "Validation blocks:",
    len(val_blocks)
)

print(
    "Internal test blocks:",
    len(test_blocks)
)
# Out:
# Train blocks: 211
# Validation blocks: 38
# Internal test blocks: 44

# %% [markdown]
# # Part 11: Fitting the scaler on traininig blocks only

# %%
scaler_training_data = pd.concat(

    [
        block[FEATURE_COLS]
        for block in train_blocks
    ],

    ignore_index=True
)

# %%
scaler_X = StandardScaler()

scaler_X.fit(
    scaler_training_data
)
# Out:
# StandardScaler()

# %%
joblib.dump(

    scaler_X,

    "cross_device_feature_scaler.pkl"
)

print(
    "Scaler fitted only on training blocks."
)
# Out:
# Scaler fitted only on training blocks.

# %% [markdown]
# # Part 12: Create sequences inside each block

# %%
def create_sequences_from_block(
    block,
    scaler,
    lookback,
    horizon,
    max_gap_seconds=5
):

    block = (
        block
        .sort_values("timestamp")
        .reset_index(drop=True)
        .copy()
    )


    scaled_features = scaler.transform(
        block[FEATURE_COLS]
    )


    temperatures = (

        block["cpuTemperature"]

        .to_numpy()
    )


    timestamps = (

        block["timestamp"]

        .to_numpy()
    )


    X = []
    y = []

    current_temperatures = []

    future_temperatures = []

    prediction_timestamps = []


    for i in range(

        lookback,

        len(block) - horizon + 1
    ):


        sequence_start = (
            i - lookback
        )


        current_index = (
            i - 1
        )


        future_index = (

            current_index

            + horizon
        )


        if future_index >= len(block):

            break


        # ------------------------------------
        # Check entire history → future period
        # ------------------------------------

        relevant_times = (

            block["timestamp"]

            .iloc[
                sequence_start:
                future_index + 1
            ]
        )


        gaps = (

            relevant_times

            .diff()

            .dt.total_seconds()

            .dropna()
        )


        if (
            gaps > max_gap_seconds
        ).any():

            continue


        # ------------------------------------
        # Input
        # ------------------------------------

        X.append(

            scaled_features[
                sequence_start:i
            ]
        )


        # ------------------------------------
        # Target
        # ------------------------------------

        current_temp = (

            temperatures[
                current_index
            ]
        )


        future_temp = (

            temperatures[
                future_index
            ]
        )


        delta_temp = (

            future_temp

            - current_temp
        )


        y.append(
            delta_temp
        )


        current_temperatures.append(
            current_temp
        )


        future_temperatures.append(
            future_temp
        )


        prediction_timestamps.append(
            timestamps[
                future_index
            ]
        )


    return (

        np.asarray(X),

        np.asarray(y),

        np.asarray(
            current_temperatures
        ),

        np.asarray(
            future_temperatures
        ),

        np.asarray(
            prediction_timestamps
        )
    )

# %% [markdown]
# # 13. Create datasets from block lists

# %%
def create_dataset_from_blocks(
    blocks,
    scaler
):

    all_X = []
    all_y = []

    all_current = []
    all_future = []

    all_timestamps = []

    all_phases = []
    all_runs = []


    for block in blocks:


        (
            X,
            y,
            current,
            future,
            timestamps

        ) = create_sequences_from_block(

            block=block,

            scaler=scaler,

            lookback=LOOKBACK,

            horizon=HORIZON
        )


        if len(X) == 0:

            continue


        phase = (
            block[
                "phaseGroup"
            ].iloc[0]
        )


        run_name = (
            block[
                "runName"
            ].iloc[0]
        )


        all_X.append(X)

        all_y.append(y)

        all_current.append(
            current
        )

        all_future.append(
            future
        )

        all_timestamps.append(
            timestamps
        )


        all_phases.extend(

            [phase] * len(X)
        )


        all_runs.extend(

            [run_name] * len(X)
        )


    return (

        np.concatenate(all_X),

        np.concatenate(all_y),

        np.concatenate(all_current),

        np.concatenate(all_future),

        np.concatenate(all_timestamps),

        np.asarray(all_phases),

        np.asarray(all_runs)
    )

# %%
(
    X_train,
    y_train,
    train_current,
    train_actual,
    train_timestamps,
    train_phases,
    train_runs

) = create_dataset_from_blocks(

    train_blocks,

    scaler_X
)

# %%
# TUNED: data cleaning on the training target only.
# Extreme dT values are almost always transient sensor glitches rather than
# real 20s temperature swings. We winsorize the TRAINING target to the
# 1st-99th percentile so the model isn't pulled toward noise, while leaving
# validation/test targets untouched so evaluation metrics stay honest.
y_train_lower = np.percentile(y_train, 1)
y_train_upper = np.percentile(y_train, 99)

print(f"Clipping training dT targets to [{y_train_lower:.3f}, {y_train_upper:.3f}] deg C (1st-99th pct)")

y_train = np.clip(y_train, y_train_lower, y_train_upper)
# Out:
# Clipping training dT targets to [-19.000, 19.500] deg C (1st-99th pct)

# %%
(
    X_val,
    y_val,
    val_current,
    val_actual,
    val_timestamps,
    val_phases,
    val_runs

) = create_dataset_from_blocks(

    val_blocks,

    scaler_X
)

# %%
(
    X_test,
    y_test,
    test_current,
    test_actual,
    test_timestamps,
    test_phases,
    test_runs

) = create_dataset_from_blocks(

    test_blocks,

    scaler_X
)

# %%
print("\nTRAIN")
print("X:", X_train.shape)
print("y:", y_train.shape)

print("\nVALIDATION")
print("X:", X_val.shape)
print("y:", y_val.shape)

print("\nINTERNAL TEST")
print("X:", X_test.shape)
print("y:", y_test.shape)
# Out:
# TRAIN
# X: (46626, 20, 7)
# y: (46626,)
#
# VALIDATION
# X: (9251, 20, 7)
# y: (9251,)
#
# INTERNAL TEST
# X: (10726, 20, 7)
# y: (10726,)

# %% [markdown]
# # 14. Verify Actual Sequence Diversity

# %%
def show_sequence_distribution(
    phases,
    name
):

    print(
        f"\n===== {name} ====="
    )

    print(

        pd.Series(phases)

        .value_counts()
    )

# %%
show_sequence_distribution(
    train_phases,
    "TRAIN"
)

show_sequence_distribution(
    val_phases,
    "VALIDATION"
)

show_sequence_distribution(
    test_phases,
    "INTERNAL TEST"
)
# Out:
# ===== TRAIN =====
# MIXED         13246
# OTHER          7576
# CHAOS          7251
# TRANSITION     7235
# RAMP           7218
# COOLING        3931
# IDLE            169
# Name: count, dtype: int64
#
# ===== VALIDATION =====
# MIXED         2697
# OTHER         1870
# CHAOS         1358
# RAMP          1357
# TRANSITION    1349
# COOLING        620
# Name: count, dtype: int64
#
# ===== INTERNAL TEST =====
# MIXED         4033
# OTHER         2008
# RAMP          1358
# TRANSITION    1355
# CHAOS         1353
# COOLING        619
# Name: count, dtype: int64

# %% [markdown]
# # Part 15: Building the CNN+LSTM Model

# %%
from tensorflow.keras.layers import (Input, Conv1D, MaxPooling1D, LSTM, Dense, Dropout)
from tensorflow.keras.models import Model

# Using the parameters from the previous tuned run
BEST_UNITS = 40
# The previous tuned run used 0.30 dropout
BEST_DROPOUT = 0.30

inputs = Input(shape=(LOOKBACK, len(FEATURE_COLS)))

# 1D Convolution to extract local patterns
x = Conv1D(
    filters=32,
    kernel_size=3,
    activation='relu',
    padding='same'
)(inputs)

x = MaxPooling1D(pool_size=2)(x)

# Controlled Experiment: Replacing GRU with LSTM
x = LSTM(
    BEST_UNITS,
    recurrent_dropout=0.1,
    kernel_regularizer=tf.keras.regularizers.l2(1e-4)
)(x)

x = Dropout(BEST_DROPOUT)(x)

x = Dense(
    16,
    activation='relu',
    kernel_regularizer=tf.keras.regularizers.l2(1e-4)
)(x)

x = Dropout(0.2)(x)

outputs = Dense(1)(x)

model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 20, 7)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 20, 32)         │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 10, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 40)             │        11,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 40)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,057 (51.00 KB)
#  Trainable params: 13,057 (51.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# TUNED: learning rate nudged up slightly (0.0005 -> 0.0008) since the
# shorter lookback + added regularization mean the model needs a bit more
# step size to converge in the same number of epochs. clipnorm=1.0 added for
# training stability (guards against occasional large gradients from any
# remaining outliers).
model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.0008,
        clipnorm=1.0
    ),
    loss=tf.keras.losses.Huber(delta=2.0),
    metrics=["mae"]
)

# %% [markdown]
# # Part 16: Train

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    min_delta=0.01,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-6,
    verbose=1
)

# Updated filename for the LSTM model checkpoint
checkpoint = ModelCheckpoint(
    'best_cross_device_lstm.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# %% [markdown]
# Train

# %%
# TUNED: batch_size 64 -> 32. Smaller batches give noisier, more frequent
# gradient updates, which for this dataset size tends to generalize slightly
# better than large batches (a mild regularizing effect) at some cost to
# training speed.
history = model.fit(

    X_train,
    y_train,

    validation_data=(
        X_val,
        y_val
    ),

    epochs=100,

    batch_size=32,

    shuffle=True,

    callbacks=[
        early_stopping,
        reduce_lr,
        checkpoint
    ],

    verbose=1
)
# Out:
# Epoch 1/100
# 1455/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9027 - mae: 2.5539
# Epoch 1: val_loss improved from None to 3.39663, saving model to best_cross_device_lstm.keras
#
# Epoch 1: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - loss: 3.8969 - mae: 2.5556 - val_loss: 3.3966 - val_mae: 2.2695 - learning_rate: 8.0000e-04
# Epoch 2/100
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8085 - mae: 2.5213
# Epoch 2: val_loss improved from 3.39663 to 3.05547, saving model to best_cross_device_lstm.keras
#
# Epoch 2: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 3.7041 - mae: 2.4750 - val_loss: 3.0555 - val_mae: 2.1068 - learning_rate: 8.0000e-04
# Epoch 3/100
# 1455/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3294 - mae: 2.2809
# Epoch 3: val_loss improved from 3.05547 to 2.93212, saving model to best_cross_device_lstm.keras
#
# Epoch 3: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 3.2973 - mae: 2.2622 - val_loss: 2.9321 - val_mae: 2.0339 - learning_rate: 8.0000e-04
# Epoch 4/100
# 1456/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1654 - mae: 2.1857
# Epoch 4: val_loss improved from 2.93212 to 2.89301, saving model to best_cross_device_lstm.keras
#
# Epoch 4: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 3.1736 - mae: 2.1898 - val_loss: 2.8930 - val_mae: 2.0092 - learning_rate: 8.0000e-04
# Epoch 5/100
# 1455/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0828 - mae: 2.1397
# Epoch 5: val_loss improved from 2.89301 to 2.84976, saving model to best_cross_device_lstm.keras
#
# Epoch 5: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 3.0986 - mae: 2.1504 - val_loss: 2.8498 - val_mae: 1.9862 - learning_rate: 8.0000e-04
# Epoch 6/100
# 1456/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0498 - mae: 2.1228
# Epoch 6: val_loss improved from 2.84976 to 2.82294, saving model to best_cross_device_lstm.keras
#
# Epoch 6: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 3.0580 - mae: 2.1278 - val_loss: 2.8229 - val_mae: 1.9751 - learning_rate: 8.0000e-04
# Epoch 7/100
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0182 - mae: 2.1042
# Epoch 7: val_loss improved from 2.82294 to 2.81353, saving model to best_cross_device_lstm.keras
#
# Epoch 7: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 3.0303 - mae: 2.1124 - val_loss: 2.8135 - val_mae: 1.9692 - learning_rate: 8.0000e-04
# Epoch 8/100
# 1457/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9783 - mae: 2.0814
# Epoch 8: val_loss improved from 2.81353 to 2.79015, saving model to best_cross_device_lstm.keras
#
# Epoch 8: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.9908 - mae: 2.0900 - val_loss: 2.7901 - val_mae: 1.9516 - learning_rate: 8.0000e-04
# Epoch 9/100
# 1455/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9546 - mae: 2.0682
# Epoch 9: val_loss improved from 2.79015 to 2.78722, saving model to best_cross_device_lstm.keras
#
# Epoch 9: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.9741 - mae: 2.0800 - val_loss: 2.7872 - val_mae: 1.9473 - learning_rate: 8.0000e-04
# Epoch 10/100
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9395 - mae: 2.0613
# Epoch 10: val_loss improved from 2.78722 to 2.76318, saving model to best_cross_device_lstm.keras
#
# Epoch 10: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.9502 - mae: 2.0684 - val_loss: 2.7632 - val_mae: 1.9409 - learning_rate: 8.0000e-04
# Epoch 11/100
# 1456/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9153 - mae: 2.0474
# Epoch 11: val_loss did not improve from 2.76318
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.9335 - mae: 2.0592 - val_loss: 2.7633 - val_mae: 1.9401 - learning_rate: 8.0000e-04
# Epoch 12/100
# 1454/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9013 - mae: 2.0400
# Epoch 12: val_loss did not improve from 2.76318
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.9282 - mae: 2.0562 - val_loss: 2.7760 - val_mae: 1.9506 - learning_rate: 8.0000e-04
# Epoch 13/100
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8973 - mae: 2.0395
# Epoch 13: val_loss improved from 2.76318 to 2.73286, saving model to best_cross_device_lstm.keras
#
# Epoch 13: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 2.9161 - mae: 2.0488 - val_loss: 2.7329 - val_mae: 1.9193 - learning_rate: 8.0000e-04
# Epoch 14/100
# 1457/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8651 - mae: 2.0202
# Epoch 14: val_loss did not improve from 2.73286
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.8955 - mae: 2.0363 - val_loss: 2.7355 - val_mae: 1.9215 - learning_rate: 8.0000e-04
# Epoch 15/100
# 1457/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8612 - mae: 2.0178
# Epoch 15: val_loss improved from 2.73286 to 2.73164, saving model to best_cross_device_lstm.keras
#
# Epoch 15: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.8938 - mae: 2.0365 - val_loss: 2.7316 - val_mae: 1.9163 - learning_rate: 8.0000e-04
# Epoch 16/100
# 1457/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8618 - mae: 2.0164
# Epoch 16: val_loss did not improve from 2.73164
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - loss: 2.8777 - mae: 2.0280 - val_loss: 2.7382 - val_mae: 1.9285 - learning_rate: 8.0000e-04
# Epoch 17/100
# 1457/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8521 - mae: 2.0121
# Epoch 17: val_loss did not improve from 2.73164
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.8744 - mae: 2.0255 - val_loss: 2.7349 - val_mae: 1.9157 - learning_rate: 8.0000e-04
# Epoch 18/100
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8382 - mae: 2.0040
# Epoch 18: val_loss did not improve from 2.73164
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.8610 - mae: 2.0182 - val_loss: 2.7341 - val_mae: 1.9220 - learning_rate: 8.0000e-04
# Epoch 19/100
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8330 - mae: 2.0019
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
#
# Epoch 19: val_loss did not improve from 2.73164
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 2.8467 - mae: 2.0096 - val_loss: 2.7327 - val_mae: 1.9172 - learning_rate: 8.0000e-04
# Epoch 20/100
# 1454/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8050 - mae: 1.9823
# Epoch 20: val_loss improved from 2.73164 to 2.72572, saving model to best_cross_device_lstm.keras
#
# Epoch 20: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.8094 - mae: 1.9857 - val_loss: 2.7257 - val_mae: 1.9158 - learning_rate: 4.0000e-04
# Epoch 21/100
# 1457/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7842 - mae: 1.9738
# Epoch 21: val_loss improved from 2.72572 to 2.71883, saving model to best_cross_device_lstm.keras
#
# Epoch 21: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.7989 - mae: 1.9826 - val_loss: 2.7188 - val_mae: 1.9102 - learning_rate: 4.0000e-04
# Epoch 22/100
# 1454/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7787 - mae: 1.9677
# Epoch 22: val_loss improved from 2.71883 to 2.70596, saving model to best_cross_device_lstm.keras
#
# Epoch 22: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.8023 - mae: 1.9828 - val_loss: 2.7060 - val_mae: 1.8990 - learning_rate: 4.0000e-04
# Epoch 23/100
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7703 - mae: 1.9641
# Epoch 23: val_loss did not improve from 2.70596
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.7852 - mae: 1.9745 - val_loss: 2.7086 - val_mae: 1.9066 - learning_rate: 4.0000e-04
# Epoch 24/100
# 1456/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7776 - mae: 1.9687
# Epoch 24: val_loss did not improve from 2.70596
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 2.7848 - mae: 1.9737 - val_loss: 2.7136 - val_mae: 1.9070 - learning_rate: 4.0000e-04
# Epoch 25/100
# 1457/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7523 - mae: 1.9531
# Epoch 25: val_loss did not improve from 2.70596
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.7754 - mae: 1.9684 - val_loss: 2.7148 - val_mae: 1.9104 - learning_rate: 4.0000e-04
# Epoch 26/100
# 1457/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7458 - mae: 1.9519
# Epoch 26: val_loss improved from 2.70596 to 2.70390, saving model to best_cross_device_lstm.keras
#
# Epoch 26: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.7760 - mae: 1.9698 - val_loss: 2.7039 - val_mae: 1.9022 - learning_rate: 4.0000e-04
# Epoch 27/100
# 1455/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7585 - mae: 1.9589
# Epoch 27: val_loss did not improve from 2.70390
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.7724 - mae: 1.9674 - val_loss: 2.7053 - val_mae: 1.9004 - learning_rate: 4.0000e-04
# Epoch 28/100
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7571 - mae: 1.9570
# Epoch 28: val_loss did not improve from 2.70390
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.7710 - mae: 1.9656 - val_loss: 2.7084 - val_mae: 1.9038 - learning_rate: 4.0000e-04
# Epoch 29/100
# 1457/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7615 - mae: 1.9600
# Epoch 29: val_loss improved from 2.70390 to 2.69715, saving model to best_cross_device_lstm.keras
#
# Epoch 29: finished saving model to best_cross_device_lstm.keras
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.7771 - mae: 1.9699 - val_loss: 2.6972 - val_mae: 1.8942 - learning_rate: 4.0000e-04
# Epoch 30/100
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7413 - mae: 1.9481
# Epoch 30: val_loss did not improve from 2.69715
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.7658 - mae: 1.9634 - val_loss: 2.7018 - val_mae: 1.9003 - learning_rate: 4.0000e-04
# Epoch 31/100
# 1456/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7445 - mae: 1.9483
# Epoch 31: val_loss did not improve from 2.69715
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 2.7571 - mae: 1.9575 - val_loss: 2.7093 - val_mae: 1.9051 - learning_rate: 4.0000e-04
# Epoch 32/100
# 1454/1458 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7576 - mae: 1.9572
# Epoch 32: val_loss did not improve from 2.69715
# 1458/1458 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 2.7571 - mae: 1.9590 - val_loss: 2.6996 - val_mae: 1.9005 - learning_rate: 4.0000e-04
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.

# %%
def calculate_metrics(actual, predicted, name):

    mae = mean_absolute_error(
        actual,
        predicted
    )

    rmse = np.sqrt(
        mean_squared_error(
            actual,
            predicted
        )
    )

    r2 = r2_score(
        actual,
        predicted
    )

    print(f"\n===== {name} =====")
    print(f"MAE:  {mae:.3f} °C")
    print(f"RMSE: {rmse:.3f} °C")
    print(f"R²:   {r2:.4f}")

    return {
        "Model": name,
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    }

# %% [markdown]
# **FIX:** The next cell loads the checkpointed *best* model and computes `test_lstm_predictions` correctly. The evaluation below reflects the best LSTM checkpoint.

# %%
# Load the actual best checkpoint explicitly (LSTM version)
best_model = tf.keras.models.load_model(
    'best_cross_device_lstm.keras'
)

# Predict temperature change
test_predicted_delta = (
    best_model.predict(X_test)
    .flatten()
)

# Reconstruct future temperature
test_lstm_predictions = (
    test_current
    + test_predicted_delta
)

# Persistence baseline:
test_persistence = test_current.copy()
# Out:
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step

# %%
internal_baseline = calculate_metrics(

    test_actual,

    test_persistence,

    "Internal Test - Persistence"
)
# Out:
# ===== Internal Test - Persistence =====
# MAE:  2.795 °C
# RMSE: 5.648 °C
# R²:   0.8512

# %%
internal_lstm = calculate_metrics(
    test_actual,
    test_lstm_predictions,
    'Internal Test - LSTM'
)
# Out:
# ===== Internal Test - LSTM =====
# MAE:  2.210 °C
# RMSE: 4.825 °C
# R²:   0.8914

# %%
import numpy as np
import tensorflow as tf
import tf2onnx
import onnxruntime as ort

KERAS_MODEL_PATH = "best_cross_device_lstm.keras"
ONNX_MODEL_PATH = "best_cross_device_lstmcnn.onnx"

# ---------------------------------------------------------
# 1. LOAD KERAS MODEL
# ---------------------------------------------------------
print("\nLoading Keras model...")
keras_model = tf.keras.models.load_model(KERAS_MODEL_PATH, compile=False)

print("Keras model loaded successfully.")
print("Input shape:", keras_model.input_shape)
print("Output shape:", keras_model.output_shape)

# ---------------------------------------------------------
# 2. CREATE EXPLICIT INFERENCE FUNCTION
# ---------------------------------------------------------
# Corrected to 7 features to match FEATURE_COLS
input_signature = [
    tf.TensorSpec(
        shape=(None, 20, 7),
        dtype=tf.float32,
        name="telemetry_input"
    )
]

@tf.function(input_signature=input_signature)
def inference_function(telemetry_input):
    prediction = keras_model(telemetry_input, training=False)
    return {"predicted_delta_t": prediction}

# ---------------------------------------------------------
# 3. CONVERT FUNCTION TO ONNX
# ---------------------------------------------------------
print("\nConverting model to ONNX...")
tf2onnx.convert.from_function(
    inference_function,
    input_signature=input_signature,
    opset=17,
    output_path=ONNX_MODEL_PATH
)

print("ONNX model saved successfully.")
print("Saved at:", ONNX_MODEL_PATH)

# ---------------------------------------------------------
# 4. CREATE IDENTICAL TEST INPUT
# ---------------------------------------------------------
np.random.seed(42)
test_input = np.random.randn(1, 20, 7).astype(np.float32)
print("\nTest input shape:", test_input.shape)

# ---------------------------------------------------------
# 5. KERAS PREDICTION
# ---------------------------------------------------------
keras_prediction = keras_model.predict(test_input, verbose=0)
keras_delta_t = float(keras_prediction[0][0])

# ---------------------------------------------------------
# 6. ONNX PREDICTION
# ---------------------------------------------------------
onnx_session = ort.InferenceSession(ONNX_MODEL_PATH, providers=["CPUExecutionProvider"])
onnx_input = onnx_session.get_inputs()[0]
onnx_output = onnx_session.get_outputs()[0]

onnx_prediction = onnx_session.run(None, {onnx_input.name: test_input})
onnx_delta_t = float(np.asarray(onnx_prediction[0]).reshape(-1)[0])

# ---------------------------------------------------------
# 7. COMPARE
# ---------------------------------------------------------
difference = abs(keras_delta_t - onnx_delta_t)
print("\n========================================")
print("       CONVERSION VALIDATION RESULT")
print("========================================")
print(f"Keras Delta T : {keras_delta_t:.10f}")
print(f"ONNX Delta T  : {onnx_delta_t:.10f}")
print(f"Difference    : {difference:.10f}")

if difference < 1e-4:
    print("\nSUCCESS: ONNX model matches Keras model.")
else:
    print("\nWARNING: Predictions differ more than expected.")
# Out:
# Loading Keras model...
# Keras model loaded successfully.
# Input shape: (None, 20, 7)
# Output shape: (None, 1)
#
# Converting model to ONNX...
# WARNING:tf2onnx.tf_loader:TF freezing failed. Attempting to fix freezing errors.
# WARNING:tf2onnx.tf_loader:Removed Fill functional_1_1/lstm_1_1/AssignVariableOp_3
# WARNING:tf2onnx.tf_loader:Removed Shape functional_1_1/lstm_1_1/AssignVariableOp_2
# WARNING:tf2onnx.tf_loader:Removed ExpandDims functional_1_1/lstm_1_1/AssignVariableOp_1
# WARNING:tf2onnx.tf_loader:Removed Squeeze functional_1_1/lstm_1_1/AssignVariableOp
# ONNX model saved successfully.
# Saved at: best_cross_device_lstmcnn.onnx
#
# Test input shape: (1, 20, 7)
#
# ========================================
#        CONVERSION VALIDATION RESULT
# ========================================
# Keras Delta T : 17.5475196838
# ONNX Delta T  : 17.5475215912
# Difference    : 0.0000019073
#
# SUCCESS: ONNX model matches Keras model.

# %%
def evaluate_by_phase(

    actual,
    predicted,
    phases,
    model_name
):

    results = []


    for phase in np.unique(
        phases
    ):

        mask = (
            phases == phase
        )


        if mask.sum() < 10:

            continue


        mae = mean_absolute_error(

            actual[mask],

            predicted[mask]
        )


        rmse = np.sqrt(

            mean_squared_error(

                actual[mask],

                predicted[mask]
            )
        )


        results.append({

            "Model":
                model_name,

            "Phase":
                phase,

            "Samples":
                mask.sum(),

            "MAE":
                mae,

            "RMSE":
                rmse
        })


    return pd.DataFrame(
        results
    )

# %%
lstm_phase_results = evaluate_by_phase(
    test_actual,
    test_lstm_predictions,
    test_phases,
    "LSTM"
)
display(lstm_phase_results)
# Out:
#   Model       Phase  Samples       MAE      RMSE
# 0  LSTM       CHAOS     1353  2.473980  5.311197
# 1  LSTM     COOLING      619  1.636893  3.124048
# 2  LSTM       MIXED     4033  2.279888  4.996207
# 3  LSTM       OTHER     2008  2.021328  4.278310
# 4  LSTM        RAMP     1358  2.096449  4.390122
# 5  LSTM  TRANSITION     1355  2.395900  5.561139

# %%
baseline_phase_results = evaluate_by_phase(

    test_actual,

    test_persistence,

    test_phases,

    "Persistence"
)

# %%
phase_comparison = pd.concat(
    [
        baseline_phase_results,
        lstm_phase_results
    ],
    ignore_index=True
)

display(
    phase_comparison.sort_values(["Phase", "Model"])
)
# Out:
#           Model       Phase  Samples       MAE      RMSE
# 6          LSTM       CHAOS     1353  2.473980  5.311197
# 0   Persistence       CHAOS     1353  2.989505  5.943661
# 7          LSTM     COOLING      619  1.636893  3.124048
# 1   Persistence     COOLING      619  2.643942  4.637945
# 8          LSTM       MIXED     4033  2.279888  4.996207
# 2   Persistence       MIXED     4033  3.039425  5.998609
# 9          LSTM       OTHER     2008  2.021328  4.278310
# 3   Persistence       OTHER     2008  2.333466  4.978666
# 10         LSTM        RAMP     1358  2.096449  4.390122
# 4   Persistence        RAMP     1358  2.447496  4.800030
# 11         LSTM  TRANSITION     1355  2.395900  5.561139
# 5   Persistence  TRANSITION     1355  2.973432  6.361465
